# %% [markdown]
# # Merging Years 2012-2017

# %% [markdown]
# ### Import pandas package

# %%
import pandas as pd

# %% [markdown]
# ## Import all datasets needed for merge

# %%
nfl2012_2016 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2016merge.csv')
off2017 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2017_offense.csv')
def2017 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2017_defense.csv')
wl2017 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_win_lose/NFL_2017_wl.csv')

# %%
nfl2012_2016.head()
# Out:
#    Unnamed: 0               Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0           0  Arizona Cardinals          250       15.6         1204
# 1           1    Atlanta Falcons          419       26.2         1397
# 2           2   Baltimore Ravens          398       24.9         1901
# 3           3      Buffalo Bills          344       21.5         2217
# 4           4  Carolina Panthers          357       22.3         2088
#
#    Off RYds/G  Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  ...  \
# 0        75.2         3005       187.8        4209      263.1  ...
# 1        87.3         4509       281.8        5906      369.1  ...
# 2       118.8         3739       233.7        5640      352.5  ...
# 3       138.6         3269       204.3        5486      342.9  ...
# 4       130.5         3683       230.2        5771      360.7  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
off2017.head()
# Out:
#    Unnamed: 0                       Team  2017 Off Tot Pts  2017 Off Pts/G  \
# 0          21   Arizona CardinalsArizona               295            18.4
# 1           7     Atlanta FalconsAtlanta               353            22.1
# 2          26  Baltimore RavensBaltimore               395            24.7
# 3          28       Buffalo BillsBuffalo               302            18.9
# 4          18  Carolina PanthersCarolina               363            22.7
#
#    2017 Off RushYds  2017 Off RYds/G  2017 Off PassYds  2017 Off PYds/G  \
# 0              1386             86.6              3640            227.5
# 1              1847            115.4              3990            249.4
# 2              1856            116.0              3030            189.4
# 3              2017            126.1              2825            176.6
# 4              2102            131.4              3077            192.3
#
#    2017 Off TotYds  2017 Off Yds/G
# 0             5026           314.1
# ...

# %%
def2017.head()
# Out:
#    Unnamed: 0                       Team  2017 Def Tot/Pts  2017 Def Pts/G  \
# 0           5   Arizona CardinalsArizona               361            22.6
# 1           8     Atlanta FalconsAtlanta               315            19.7
# 2          11  Baltimore RavensBaltimore               303            18.9
# 3          25       Buffalo BillsBuffalo               359            22.4
# 4           6  Carolina PanthersCarolina               327            20.4
#
#    2017 Def RushYds  2017 Def RYds/G  2017 Def PassYds  2017 Def PYds/G  \
# 0              1434             89.6              3541            221.3
# 1              1665            104.1              3429            214.3
# 2              1780            111.2              3421            213.8
# 3              1994            124.6              3688            230.5
# 4              1409             88.1              3665            229.1
#
#    2017 Def TotYds  2017 Def Yds/G
# 0             4975           310.9
# ...

# %%
wl2017.head()
# Out:
#    Unnamed: 0               Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0          14  Arizona Cardinals     8       8    0        No     No  2017
# 1          22    Atlanta Falcons    10       6    0        No     No  2017
# 2          15   Baltimore Ravens     9       7    0        No     No  2017
# 3          16      Buffalo Bills     9       7    0        No     No  2017
# 4          25  Carolina Panthers    11       5    0        No     No  2017

# %% [markdown]
# ### Drop unnamed column from all datasets

# %%
nfl2012_2016 = nfl2012_2016.iloc[:, 1:]
off2017 = off2017.iloc[:, 1:]
def2017 = def2017.iloc[:, 1:]
wl2017 = wl2017.iloc[:, 1:]

# %%
nfl2012_2016.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
off2017.head()
# Out:
#                         Team  2017 Off Tot Pts  2017 Off Pts/G  \
# 0   Arizona CardinalsArizona               295            18.4
# 1     Atlanta FalconsAtlanta               353            22.1
# 2  Baltimore RavensBaltimore               395            24.7
# 3       Buffalo BillsBuffalo               302            18.9
# 4  Carolina PanthersCarolina               363            22.7
#
#    2017 Off RushYds  2017 Off RYds/G  2017 Off PassYds  2017 Off PYds/G  \
# 0              1386             86.6              3640            227.5
# 1              1847            115.4              3990            249.4
# 2              1856            116.0              3030            189.4
# 3              2017            126.1              2825            176.6
# 4              2102            131.4              3077            192.3
#
#    2017 Off TotYds  2017 Off Yds/G
# 0             5026           314.1
# 1             5837           364.8
# 2             4886           305.4
# ...

# %%
def2017.head()
# Out:
#                         Team  2017 Def Tot/Pts  2017 Def Pts/G  \
# 0   Arizona CardinalsArizona               361            22.6
# 1     Atlanta FalconsAtlanta               315            19.7
# 2  Baltimore RavensBaltimore               303            18.9
# 3       Buffalo BillsBuffalo               359            22.4
# 4  Carolina PanthersCarolina               327            20.4
#
#    2017 Def RushYds  2017 Def RYds/G  2017 Def PassYds  2017 Def PYds/G  \
# 0              1434             89.6              3541            221.3
# 1              1665            104.1              3429            214.3
# 2              1780            111.2              3421            213.8
# 3              1994            124.6              3688            230.5
# 4              1409             88.1              3665            229.1
#
#    2017 Def TotYds  2017 Def Yds/G
# 0             4975           310.9
# 1             5094           318.4
# 2             5201           325.1
# ...

# %%
wl2017.head()
# Out:
#                 Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0  Arizona Cardinals     8       8    0        No     No  2017
# 1    Atlanta Falcons    10       6    0        No     No  2017
# 2   Baltimore Ravens     9       7    0        No     No  2017
# 3      Buffalo Bills     9       7    0        No     No  2017
# 4  Carolina Panthers    11       5    0        No     No  2017

# %% [markdown]
# ### Rename columns in off/def data

# %%
offense2017 = off2017.rename(columns ={"2017 Off Tot Pts": "Off Tot/Pts", "2017 Off Pts/G": "Off Pts/G",
                                                     "2017 Off RushYds": "Off RushYds", "2017 Off RYds/G": "Off RYds/G",
                                                     "2017 Off PassYds": "Off PassYds", "2017 Off PYds/G": "Off PYds/G",
                                                     "2017 Off TotYds": "Off TotYds", "2017 Off Yds/G": "Off Yds/G"})
defense2017 = def2017.rename(columns ={"2017 Def Tot/Pts": "Def Tot/Pts", "2017 Def Pts/G": "Def Pts/G",
                                                     "2017 Def RushYds": "Def RushYds", "2017 Def RYds/G": "Def RYds/G",
                                                     "2017 Def PassYds": "Def PassYds", "2017 Def PYds/G": "Def PYds/G",
                                                     "2017 Def TotYds": "Def TotYds", "2017 Def Yds/G": "Def Yds/G"})

# %%
offense2017.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          295       18.4         1386        86.6
# 1     Atlanta FalconsAtlanta          353       22.1         1847       115.4
# 2  Baltimore RavensBaltimore          395       24.7         1856       116.0
# 3       Buffalo BillsBuffalo          302       18.9         2017       126.1
# 4  Carolina PanthersCarolina          363       22.7         2102       131.4
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G
# 0         3640       227.5        5026      314.1
# 1         3990       249.4        5837      364.8
# 2         3030       189.4        4886      305.4
# 3         2825       176.6        4842      302.6
# 4         3077       192.3        5179      323.7

# %%
defense2017.head()
# Out:
#                         Team  Def Tot/Pts  Def Pts/G  Def RushYds  Def RYds/G  \
# 0   Arizona CardinalsArizona          361       22.6         1434        89.6
# 1     Atlanta FalconsAtlanta          315       19.7         1665       104.1
# 2  Baltimore RavensBaltimore          303       18.9         1780       111.2
# 3       Buffalo BillsBuffalo          359       22.4         1994       124.6
# 4  Carolina PanthersCarolina          327       20.4         1409        88.1
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# 0         3541       221.3        4975      310.9
# 1         3429       214.3        5094      318.4
# 2         3421       213.8        5201      325.1
# 3         3688       230.5        5682      355.1
# 4         3665       229.1        5074      317.1

# %% [markdown]
# ### Merge Offense and Defense Data

# %%
off_def2017 = pd.merge(offense2017, defense2017, on='Team')

# %%
off_def2017.head(32)
# Out:
#                                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0           Arizona CardinalsArizona          295       18.4         1386
# 1             Atlanta FalconsAtlanta          353       22.1         1847
# 2          Baltimore RavensBaltimore          395       24.7         1856
# 3               Buffalo BillsBuffalo          302       18.9         2017
# 4          Carolina PanthersCarolina          363       22.7         2102
# 5               Chicago BearsChicago          264       16.5         1788
# 6       Cincinnati BengalsCincinnati          290       18.1         1366
# 7          Cleveland BrownsCleveland          234       14.6         1714
# 8               Dallas CowboysDallas          354       22.1         2170
# 9               Denver BroncosDenver          289       18.1         1852
# 10              Detroit LionsDetroit          410       25.6         1221
# 11        Green Bay PackersGreen Bay          320       20.0         1724
# ...

# %% [markdown]
# ### Rename Teams to match merge data

# %%
teamnames17 = {'Arizona CardinalsArizona': 'Arizona Cardinals', 'Atlanta FalconsAtlanta': 'Atlanta Falcons', 
             'Baltimore RavensBaltimore': 'Baltimore Ravens', 'Buffalo BillsBuffalo': 'Buffalo Bills',
            'Carolina PanthersCarolina': 'Carolina Panthers', 'Chicago BearsChicago': 'Chicago Bears',
            'Cincinnati BengalsCincinnati': 'Cincinnati Bengals', 'Cleveland BrownsCleveland': 'Cleveland Browns',
            'Dallas CowboysDallas': 'Dallas Cowboys', 'Denver BroncosDenver': 'Denver Broncos', 
             'Detroit LionsDetroit': 'Detroit Lions', 'Green Bay PackersGreen Bay': 'Green Bay Packers',
            'Houston TexansHouston': 'Houston Texans', 'Indianapolis ColtsIndianapolis': 'Indianapolis Colts',
            'Jacksonville JaguarsJacksonville': 'Jacksonville Jaguars', 'Kansas City ChiefsKansas City': 'Kansas City Chiefs',
            'Los Angeles ChargersLA Chargers': 'Los Angeles Chargers', 'Los Angeles RamsLA Rams': 'Los Angeles Rams',
            'Miami DolphinsMiami': 'Miami Dolphins', 'Minnesota VikingsMinnesota': 'Minnesota Vikings', 
            'New England PatriotsNew England': 'New England Patriots', 'New Orleans SaintsNew Orleans': 'New Orleans Saints',
            'New York GiantsNY Giants': 'New York Giants', 'New York JetsNY Jets': 'New York Jets', 
            'Oakland RaidersOakland': 'Las Vegas Raiders', 'Philadelphia EaglesPhiladelphia': 'Philadelphia Eagles',
            'Pittsburgh SteelersPittsburgh': 'Pittsburgh Steelers',
            'San Francisco 49ersSan Francisco': 'San Francisco 49ers', 'Seattle SeahawksSeattle': 'Seattle Seahawks', 
            'Tampa Bay BuccaneersTampa Bay': 'Tampa Bay Buccaneers', 'Tennessee TitansTennessee': 'Tennessee Titans',
            'Washington RedskinsWashington': 'Washington Commanders'}
off_def2017['Team'] = off_def2017['Team'].replace(teamnames17)

# %%
off_def2017.tail(16)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 16   Los Angeles Chargers          355       22.2         1595        99.7
# 17       Los Angeles Rams          478       29.9         1953       122.1
# 18         Miami Dolphins          281       17.6         1388        86.8
# 19      Minnesota Vikings          382       23.9         1957       122.3
# 20   New England Patriots          458       28.6         1889       118.1
# 21     New Orleans Saints          448       28.0         2070       129.4
# 22        New York Giants          246       15.4         1549        96.8
# 23          New York Jets          298       18.6         1702       106.4
# 24      Las Vegas Raiders          301       18.8         1554        97.1
# 25    Philadelphia Eagles          457       28.6         2115       132.2
# 26    Pittsburgh Steelers          406       25.4         1667       104.2
# ...

# %% [markdown]
# ### Put Dataset in Team Ascending Order

# %%
off_def2017 = off_def2017.sort_values("Team")

# %%
off_def2017.tail(16)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 24      Las Vegas Raiders          301       18.8         1554        97.1
# 16   Los Angeles Chargers          355       22.2         1595        99.7
# 17       Los Angeles Rams          478       29.9         1953       122.1
# 18         Miami Dolphins          281       17.6         1388        86.8
# 19      Minnesota Vikings          382       23.9         1957       122.3
# 20   New England Patriots          458       28.6         1889       118.1
# 21     New Orleans Saints          448       28.0         2070       129.4
# 22        New York Giants          246       15.4         1549        96.8
# 23          New York Jets          298       18.6         1702       106.4
# 25    Philadelphia Eagles          457       28.6         2115       132.2
# 26    Pittsburgh Steelers          406       25.4         1667       104.2
# ...

# %% [markdown]
# ### Merge with Win/Loss Data

# %%
nfl2017 = pd.merge(off_def2017, wl2017, on="Team")

# %%
nfl2017.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          295       18.4         1386        86.6
# 1    Atlanta Falcons          353       22.1         1847       115.4
# 2   Baltimore Ravens          395       24.7         1856       116.0
# 3      Buffalo Bills          302       18.9         2017       126.1
# 4  Carolina Panthers          363       22.7         2102       131.4
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3640       227.5        5026      314.1          361  ...
# 1         3990       249.4        5837      364.8          315  ...
# 2         3030       189.4        4886      305.4          303  ...
# 3         2825       176.6        4842      302.6          359  ...
# 4         3077       192.3        5179      323.7          327  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2017.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2017complete.csv')

# %% [markdown]
# ### Merge 2012-2017 Data

# %%
nfl2012_2017 = pd.concat([nfl2012_2016, nfl2017], axis=0, join='outer', ignore_index='True')

# %%
nfl2012_2017.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
nfl2012_2017.tail()
# Out:
#                       Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 187    San Francisco 49ers          331       20.7         1662       103.9
# 188       Seattle Seahawks          366       22.9         1629       101.8
# 189   Tampa Bay Buccaneers          335       20.9         1450        90.6
# 190       Tennessee Titans          334       20.9         1833       114.6
# 191  Washington Commanders          342       21.4         1448        90.5
#
#      Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 187         3925       245.3        5587      349.2          383  ...
# 188         3657       228.6        5286      330.4          332  ...
# 189         4366       272.9        5816      363.5          382  ...
# 190         3191       199.4        5024      314.0          356  ...
# 191         3751       234.4        5199      324.9          388  ...
#
#      Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2012_2017.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2017merge.csv')

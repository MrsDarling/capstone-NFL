# %% [markdown]
# # Merging Years 2012-2016

# %% [markdown]
# ### Import pandas package

# %%
import pandas as pd

# %% [markdown]
# ## Import all datasets needed for merge

# %%
nfl2012_2015 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2015merge.csv')
off2016 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2016_offense.csv')
def2016 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2016_defense.csv')
wl2016 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_win_lose/NFL_2016_wl.csv')

# %%
nfl2012_2015.head()
# Out:
#    Unnamed: 0               Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0           0  Arizona Cardinals          250       15.6         1204
# 1           1    Atlanta Falcons          419       26.2         1397
# 2           2   Baltimore Ravens          398       24.9         1901
# 3           3      Buffalo Bills          344       21.5         2217
# 4           4  Carolina Panthers          357       22.3         2088
#
#    Off RYds/G  Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  ...  \
# 0        75.2         3005       187.8        4209      263.1  ...
# 1        87.3         4509       281.8        5906      369.1  ...
# 2       118.8         3739       233.7        5640      352.5  ...
# 3       138.6         3269       204.3        5486      342.9  ...
# 4       130.5         3683       230.2        5771      360.7  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
off2016.head()
# Out:
#    Unnamed: 0                       Team  2016 Off Tot Pts  2016 Off Pts/G  \
# 0           8   Arizona CardinalsArizona               418            26.1
# 1           1     Atlanta FalconsAtlanta               540            33.8
# 2          16  Baltimore RavensBaltimore               343            21.4
# 3          15       Buffalo BillsBuffalo               399            24.9
# 4          18  Carolina PanthersCarolina               369            23.1
#
#    2016 Off RushYds  2016 Off RYds/G  2016 Off PassYds  2016 Off PYds/G  \
# 0              1732            108.2              4136            258.5
# 1              1928            120.5              4725            295.3
# 2              1463             91.4              4100            256.2
# 3              2630            164.4              3036            189.8
# 4              1814            113.4              3685            230.3
#
#    2016 Off TotYds  2016 Off Yds/G
# 0             5868           366.8
# ...

# %%
def2016.head()
# Out:
#    Unnamed: 0                       Team  2016 Def Tot Pts  2016 Def Pts/G  \
# 0           1   Arizona CardinalsArizona               362            22.6
# 1          24     Atlanta FalconsAtlanta               406            25.4
# 2           6  Baltimore RavensBaltimore               321            20.1
# 3          18       Buffalo BillsBuffalo               378            23.6
# 4          20  Carolina PanthersCarolina               402            25.1
#
#    2016 Def RushYds  2016 Def RYds/G  2016 Def PassYds  2016 Def PYds/G  \
# 0              1518             94.9              3365            210.3
# 1              1672            104.5              4267            266.7
# 2              1430             89.4              3724            232.8
# 3              2130            133.1              3582            223.9
# 4              1465             91.6              4291            268.2
#
#    2016 Def TotYds  2016 Def Yds/G
# 0             4883           305.2
# ...

# %%
wl2016.head()
# Out:
#    Unnamed: 0               Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0           9  Arizona Cardinals     7       8    1        No     No  2016
# 1          25    Atlanta Falcons    11       5    0       Yes     No  2016
# 2          13   Baltimore Ravens     8       8    0        No     No  2016
# 3          10      Buffalo Bills     7       9    0        No     No  2016
# 4           7  Carolina Panthers     6      10    0        No     No  2016

# %% [markdown]
# ### Drop unnamed column from all datasets

# %%
nfl2012_2015 = nfl2012_2015.iloc[:, 1:]
off2016 = off2016.iloc[:, 1:]
def2016 = def2016.iloc[:, 1:]
wl2016 = wl2016.iloc[:, 1:]

# %%
nfl2012_2015.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
off2016.head()
# Out:
#                         Team  2016 Off Tot Pts  2016 Off Pts/G  \
# 0   Arizona CardinalsArizona               418            26.1
# 1     Atlanta FalconsAtlanta               540            33.8
# 2  Baltimore RavensBaltimore               343            21.4
# 3       Buffalo BillsBuffalo               399            24.9
# 4  Carolina PanthersCarolina               369            23.1
#
#    2016 Off RushYds  2016 Off RYds/G  2016 Off PassYds  2016 Off PYds/G  \
# 0              1732            108.2              4136            258.5
# 1              1928            120.5              4725            295.3
# 2              1463             91.4              4100            256.2
# 3              2630            164.4              3036            189.8
# 4              1814            113.4              3685            230.3
#
#    2016 Off TotYds  2016 Off Yds/G
# 0             5868           366.8
# 1             6653           415.8
# 2             5563           347.7
# ...

# %%
def2016.head()
# Out:
#                         Team  2016 Def Tot Pts  2016 Def Pts/G  \
# 0   Arizona CardinalsArizona               362            22.6
# 1     Atlanta FalconsAtlanta               406            25.4
# 2  Baltimore RavensBaltimore               321            20.1
# 3       Buffalo BillsBuffalo               378            23.6
# 4  Carolina PanthersCarolina               402            25.1
#
#    2016 Def RushYds  2016 Def RYds/G  2016 Def PassYds  2016 Def PYds/G  \
# 0              1518             94.9              3365            210.3
# 1              1672            104.5              4267            266.7
# 2              1430             89.4              3724            232.8
# 3              2130            133.1              3582            223.9
# 4              1465             91.6              4291            268.2
#
#    2016 Def TotYds  2016 Def Yds/G
# 0             4883           305.2
# 1             5939           371.2
# 2             5154           322.1
# ...

# %%
wl2016.head()
# Out:
#                 Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0  Arizona Cardinals     7       8    1        No     No  2016
# 1    Atlanta Falcons    11       5    0       Yes     No  2016
# 2   Baltimore Ravens     8       8    0        No     No  2016
# 3      Buffalo Bills     7       9    0        No     No  2016
# 4  Carolina Panthers     6      10    0        No     No  2016

# %% [markdown]
# ### Rename columns in off/def data

# %%
offense2016 = off2016.rename(columns ={"2016 Off Tot Pts": "Off Tot/Pts", "2016 Off Pts/G": "Off Pts/G",
                                                     "2016 Off RushYds": "Off RushYds", "2016 Off RYds/G": "Off RYds/G",
                                                     "2016 Off PassYds": "Off PassYds", "2016 Off PYds/G": "Off PYds/G",
                                                     "2016 Off TotYds": "Off TotYds", "2016 Off Yds/G": "Off Yds/G"})
defense2016 = def2016.rename(columns ={"2016 Def Tot Pts": "Def Tot/Pts", "2016 Def Pts/G": "Def Pts/G",
                                                     "2016 Def RushYds": "Def RushYds", "2016 Def RYds/G": "Def RYds/G",
                                                     "2016 Def PassYds": "Def PassYds", "2016 Def PYds/G": "Def PYds/G",
                                                     "2016 Def TotYds": "Def TotYds", "2016 Def Yds/G": "Def Yds/G"})

# %%
offense2016.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          418       26.1         1732       108.2
# 1     Atlanta FalconsAtlanta          540       33.8         1928       120.5
# 2  Baltimore RavensBaltimore          343       21.4         1463        91.4
# 3       Buffalo BillsBuffalo          399       24.9         2630       164.4
# 4  Carolina PanthersCarolina          369       23.1         1814       113.4
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G
# 0         4136       258.5        5868      366.8
# 1         4725       295.3        6653      415.8
# 2         4100       256.2        5563      347.7
# 3         3036       189.8        5666      354.1
# 4         3685       230.3        5499      343.7

# %%
defense2016.head()
# Out:
#                         Team  Def Tot/Pts  Def Pts/G  Def RushYds  Def RYds/G  \
# 0   Arizona CardinalsArizona          362       22.6         1518        94.9
# 1     Atlanta FalconsAtlanta          406       25.4         1672       104.5
# 2  Baltimore RavensBaltimore          321       20.1         1430        89.4
# 3       Buffalo BillsBuffalo          378       23.6         2130       133.1
# 4  Carolina PanthersCarolina          402       25.1         1465        91.6
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# 0         3365       210.3        4883      305.2
# 1         4267       266.7        5939      371.2
# 2         3724       232.8        5154      322.1
# 3         3582       223.9        5712      357.0
# 4         4291       268.2        5756      359.8

# %% [markdown]
# ### Merge Offense and Defense Data

# %%
off_def2016 = pd.merge(offense2016, defense2016, on='Team')

# %%
off_def2016.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          418       26.1         1732       108.2
# 1     Atlanta FalconsAtlanta          540       33.8         1928       120.5
# 2  Baltimore RavensBaltimore          343       21.4         1463        91.4
# 3       Buffalo BillsBuffalo          399       24.9         2630       164.4
# 4  Carolina PanthersCarolina          369       23.1         1814       113.4
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  Def Pts/G  \
# 0         4136       258.5        5868      366.8          362       22.6
# 1         4725       295.3        6653      415.8          406       25.4
# 2         4100       256.2        5563      347.7          321       20.1
# 3         3036       189.8        5666      354.1          378       23.6
# 4         3685       230.3        5499      343.7          402       25.1
#
# ...

# %%
off_def2016.tail(16)
# Out:
#                            Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 16  Los Angeles RamsLos Angeles          224       14.0         1252
# 17               Miami Dolphins          363       22.7         1824
# 18            Minnesota Vikings          327       20.4         1205
# 19         New England Patriots          441       27.6         1872
# 20           New Orleans Saints          469       29.3         1742
# 21              New York Giants          310       19.4         1412
# 22                New York Jets          275       17.2         1802
# 23            Las Vegas Raiders          416       26.0         1922
# 24          Philadelphia Eagles          367       22.9         1813
# 25          Pittsburgh Steelers          399       24.9         1760
# 26         Los Angeles Chargers          410       25.6         1510
# 27          San Francisco 49ers          309       19.3         2019
# 28             Seattle Seahawks          354       22.1         1591
# ...

# %% [markdown]
# ### Rename Teams to match merge data

# %%
teamnames16 = {'Arizona CardinalsArizona': 'Arizona Cardinals', 'Atlanta FalconsAtlanta': 'Atlanta Falcons', 
             'Baltimore RavensBaltimore': 'Baltimore Ravens', 'Buffalo BillsBuffalo': 'Buffalo Bills',
            'Carolina PanthersCarolina': 'Carolina Panthers', 'Chicago BearsChicago': 'Chicago Bears',
            'Cincinnati BengalsCincinnati': 'Cincinnati Bengals', 'Cleveland BrownsCleveland': 'Cleveland Browns',
            'Dallas CowboysDallas': 'Dallas Cowboys', 'Denver BroncosDenver': 'Denver Broncos', 
             'Detroit LionsDetroit': 'Detroit Lions', 'Green Bay PackersGreen Bay': 'Green Bay Packers',
            'Houston TexansHouston': 'Houston Texans', 'Indianapolis ColtsIndianapolis': 'Indianapolis Colts',
            'Jacksonville JaguarsJacksonville': 'Jacksonville Jaguars', 'Kansas City ChiefsKansas City': 'Kansas City Chiefs',
            'Miami DolphinsMiami': 'Miami Dolphins', 'Minnesota VikingsMinnesota': 'Minnesota Vikings', 
            'New England PatriotsNew England': 'New England Patriots', 'New Orleans SaintsNew Orleans': 'New Orleans Saints',
            'New York GiantsNY Giants': 'New York Giants', 'New York JetsNY Jets': 'New York Jets', 
            'Oakland RaidersOakland': 'Las Vegas Raiders', 'Philadelphia EaglesPhiladelphia': 'Philadelphia Eagles',
            'Pittsburgh SteelersPittsburgh': 'Pittsburgh Steelers', 'San Diego ChargersSan Diego': 'Los Angeles Chargers',
            'San Francisco 49ersSan Francisco': 'San Francisco 49ers', 'Seattle SeahawksSeattle': 'Seattle Seahawks',
            'St. Louis RamsSt. Louis': 'Los Angeles Rams', 
            'Tampa Bay BuccaneersTampa Bay': 'Tampa Bay Buccaneers', 'Tennessee TitansTennessee': 'Tennessee Titans',
            'Washington RedskinsWashington': 'Washington Commanders'}
off_def2016['Team'] = off_def2016['Team'].replace(teamnames16)

# %%
off_def2016.head(32)
# Out:
#                            Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0             Arizona Cardinals          418       26.1         1732
# 1               Atlanta Falcons          540       33.8         1928
# 2              Baltimore Ravens          343       21.4         1463
# 3                 Buffalo Bills          399       24.9         2630
# 4             Carolina Panthers          369       23.1         1814
# 5                 Chicago Bears          279       17.4         1735
# 6            Cincinnati Bengals          325       20.3         1769
# 7              Cleveland Browns          264       16.5         1712
# 8                Dallas Cowboys          421       26.3         2396
# 9                Denver Broncos          333       20.8         1484
# 10                Detroit Lions          346       21.6         1310
# 11            Green Bay Packers          432       27.0         1701
# 12               Houston Texans          279       17.4         1859
# ...

# %% [markdown]
# ### Fix Los Angeles Rams Name

# %%
teamnames_16 = {'Los Angeles RamsLos Angeles': 'Los Angeles Rams'}
off_def2016['Team'] = off_def2016['Team'].replace(teamnames_16)

# %%
off_def2016.head(32)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0       Arizona Cardinals          418       26.1         1732       108.2
# 1         Atlanta Falcons          540       33.8         1928       120.5
# 2        Baltimore Ravens          343       21.4         1463        91.4
# 3           Buffalo Bills          399       24.9         2630       164.4
# 4       Carolina Panthers          369       23.1         1814       113.4
# 5           Chicago Bears          279       17.4         1735       108.4
# 6      Cincinnati Bengals          325       20.3         1769       110.6
# 7        Cleveland Browns          264       16.5         1712       107.0
# 8          Dallas Cowboys          421       26.3         2396       149.8
# 9          Denver Broncos          333       20.8         1484        92.8
# 10          Detroit Lions          346       21.6         1310        81.9
# ...

# %% [markdown]
# ### Put Dataset in Team Ascending Order

# %%
off_def2016 = off_def2016.sort_values("Team")

# %%
off_def2016.tail(16)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 23      Las Vegas Raiders          416       26.0         1922       120.1
# 26   Los Angeles Chargers          410       25.6         1510        94.4
# 16       Los Angeles Rams          224       14.0         1252        78.2
# 17         Miami Dolphins          363       22.7         1824       114.0
# 18      Minnesota Vikings          327       20.4         1205        75.3
# 19   New England Patriots          441       27.6         1872       117.0
# 20     New Orleans Saints          469       29.3         1742       108.9
# 21        New York Giants          310       19.4         1412        88.2
# 22          New York Jets          275       17.2         1802       112.6
# 24    Philadelphia Eagles          367       22.9         1813       113.3
# 25    Pittsburgh Steelers          399       24.9         1760       110.0
# ...

# %% [markdown]
# ### Merge with Win/Loss Data

# %%
nfl2016 = pd.merge(off_def2016, wl2016, on="Team")

# %%
nfl2016.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          418       26.1         1732       108.2
# 1    Atlanta Falcons          540       33.8         1928       120.5
# 2   Baltimore Ravens          343       21.4         1463        91.4
# 3      Buffalo Bills          399       24.9         2630       164.4
# 4  Carolina Panthers          369       23.1         1814       113.4
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         4136       258.5        5868      366.8          362  ...
# 1         4725       295.3        6653      415.8          406  ...
# 2         4100       256.2        5563      347.7          321  ...
# 3         3036       189.8        5666      354.1          378  ...
# 4         3685       230.3        5499      343.7          402  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2016.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2016complete.csv')

# %% [markdown]
# ### Merge 2012-2016 Data

# %%
nfl2012_2016 = pd.concat([nfl2012_2015, nfl2016], axis=0, join='outer', ignore_index='True')

# %%
nfl2012_2016.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
nfl2012_2016.tail()
# Out:
#                       Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 155    San Francisco 49ers          309       19.3         2019       126.2
# 156       Seattle Seahawks          354       22.1         1591        99.4
# 157   Tampa Bay Buccaneers          354       22.1         1616       101.0
# 158       Tennessee Titans          381       23.8         2187       136.7
# 159  Washington Commanders          396       24.8         1696       106.0
#
#      Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 155         2911       181.9        4930      308.1          480  ...
# 156         4124       257.8        5715      357.2          292  ...
# 157         3926       245.4        5542      346.4          369  ...
# 158         3541       221.3        5728      358.0          378  ...
# 159         4758       297.4        6454      403.4          383  ...
#
#      Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2012_2016.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2016merge.csv')

# %% [markdown]
# # Final Project Merging Data

# %% [markdown]
# ### Import packages

# %%
import pandas as pd

# %% [markdown]
# ### Import 2012 Offense & Defense Datasets

# %%
off2012 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2012_offense.csv')

# %%
def2012 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2012_defense.csv')

# %%
off2012.head()
# Out:
#    Unnamed: 0                       Team  TotPts  2012 Off Pts/G  \
# 0          31   Arizona CardinalsArizona     250            15.6
# 1           7     Atlanta FalconsAtlanta     419            26.2
# 2          15  Baltimore RavensBaltimore     398            24.9
# 3          18       Buffalo BillsBuffalo     344            21.5
# 4          11  Carolina PanthersCarolina     357            22.3
#
#    2012 Off RushYds  2012 Off RYds/G  2012 Off PassYds  2012 Off PYds/G  \
# 0              1204             75.2              3005            187.8
# 1              1397             87.3              4509            281.8
# 2              1901            118.8              3739            233.7
# 3              2217            138.6              3269            204.3
# 4              2088            130.5              3683            230.2
#
#    2012 Off TotYds  2012 Off Yds/G
# 0             4209           263.1
# 1             5906           369.1
# ...

# %%
def2012.head()
# Out:
#    Unnamed: 0                       Team  2012 Def Tot Pts  2012 Def Pts/G  \
# 0          11   Arizona CardinalsArizona               357            22.3
# 1          23     Atlanta FalconsAtlanta               299            18.7
# 2          16  Baltimore RavensBaltimore               344            21.5
# 3          21       Buffalo BillsBuffalo               435            27.2
# 4           9  Carolina PanthersCarolina               363            22.7
#
#    2012 Def RushYds  2012 Def RYds/G  2012 Def PassYds  2012 Def PYds/G  \
# 0              2192            137.0              3213            200.8
# 1              1971            123.2              3878            242.4
# 2              1965            122.8              3650            228.1
# 3              2333            145.8              3473            217.1
# 4              1761            110.1              3568            223.0
#
#    2012 Def TotYds  2012 Def Yds/G
# 0             5405           337.8
# ...

# %% [markdown]
# ### Drop unnamed column in both datasets

# %%
off2012 = off2012.iloc[:, 1:]

# %%
off2012.head()
# Out:
#                         Team  TotPts  2012 Off Pts/G  2012 Off RushYds  \
# 0   Arizona CardinalsArizona     250            15.6              1204
# 1     Atlanta FalconsAtlanta     419            26.2              1397
# 2  Baltimore RavensBaltimore     398            24.9              1901
# 3       Buffalo BillsBuffalo     344            21.5              2217
# 4  Carolina PanthersCarolina     357            22.3              2088
#
#    2012 Off RYds/G  2012 Off PassYds  2012 Off PYds/G  2012 Off TotYds  \
# 0             75.2              3005            187.8             4209
# 1             87.3              4509            281.8             5906
# 2            118.8              3739            233.7             5640
# 3            138.6              3269            204.3             5486
# 4            130.5              3683            230.2             5771
#
#    2012 Off Yds/G
# 0           263.1
# 1           369.1
# 2           352.5
# 3           342.9
# ...

# %%
def2012 = def2012.iloc[:, 1:]

# %%
def2012.head()
# Out:
#                         Team  2012 Def Tot Pts  2012 Def Pts/G  \
# 0   Arizona CardinalsArizona               357            22.3
# 1     Atlanta FalconsAtlanta               299            18.7
# 2  Baltimore RavensBaltimore               344            21.5
# 3       Buffalo BillsBuffalo               435            27.2
# 4  Carolina PanthersCarolina               363            22.7
#
#    2012 Def RushYds  2012 Def RYds/G  2012 Def PassYds  2012 Def PYds/G  \
# 0              2192            137.0              3213            200.8
# 1              1971            123.2              3878            242.4
# 2              1965            122.8              3650            228.1
# 3              2333            145.8              3473            217.1
# 4              1761            110.1              3568            223.0
#
#    2012 Def TotYds  2012 Def Yds/G
# 0             5405           337.8
# 1             5849           365.6
# 2             5615           350.9
# ...

# %% [markdown]
# ### Rename columns

# %%
offense2012 = off2012.rename(columns ={"TotPts": "Off Tot/Pts", "2012 Off Pts/G": "Off Pts/G",
                                                     "2012 Off RushYds": "Off RushYds", "2012 Off RYds/G": "Off RYds/G",
                                                     "2012 Off PassYds": "Off PassYds", "2012 Off PYds/G": "Off PYds/G",
                                                     "2012 Off TotYds": "Off TotYds", "2012 Off Yds/G": "Off Yds/G"})

# %%
offense2012.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          250       15.6         1204        75.2
# 1     Atlanta FalconsAtlanta          419       26.2         1397        87.3
# 2  Baltimore RavensBaltimore          398       24.9         1901       118.8
# 3       Buffalo BillsBuffalo          344       21.5         2217       138.6
# 4  Carolina PanthersCarolina          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G
# 0         3005       187.8        4209      263.1
# 1         4509       281.8        5906      369.1
# 2         3739       233.7        5640      352.5
# 3         3269       204.3        5486      342.9
# 4         3683       230.2        5771      360.7

# %%
defense2012 = def2012.rename(columns ={"2012 Def Tot Pts": "Def Tot/Pts", "2012 Def Pts/G": "Def Pts/G",
                                                     "2012 Def RushYds": "Def RushYds", "2012 Def RYds/G": "Def RYds/G",
                                                     "2012 Def PassYds": "Def PassYds", "2012 Def PYds/G": "Def PYds/G",
                                                     "2012 Def TotYds": "Def TotYds", "2012 Def Yds/G": "Def Yds/G"})

# %%
defense2012.head()
# Out:
#                         Team  Def Tot/Pts  Def Pts/G  Def RushYds  Def RYds/G  \
# 0   Arizona CardinalsArizona          357       22.3         2192       137.0
# 1     Atlanta FalconsAtlanta          299       18.7         1971       123.2
# 2  Baltimore RavensBaltimore          344       21.5         1965       122.8
# 3       Buffalo BillsBuffalo          435       27.2         2333       145.8
# 4  Carolina PanthersCarolina          363       22.7         1761       110.1
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# 0         3213       200.8        5405      337.8
# 1         3878       242.4        5849      365.6
# 2         3650       228.1        5615      350.9
# 3         3473       217.1        5806      362.9
# 4         3568       223.0        5329      333.1

# %% [markdown]
# ### Merge 2012 Offense and Defense into one dataset

# %%
off_def2012 = pd.merge(offense2012, defense2012, on='Team')

# %%
off_def2012.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          250       15.6         1204        75.2
# 1     Atlanta FalconsAtlanta          419       26.2         1397        87.3
# 2  Baltimore RavensBaltimore          398       24.9         1901       118.8
# 3       Buffalo BillsBuffalo          344       21.5         2217       138.6
# 4  Carolina PanthersCarolina          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  Def Pts/G  \
# 0         3005       187.8        4209      263.1          357       22.3
# 1         4509       281.8        5906      369.1          299       18.7
# 2         3739       233.7        5640      352.5          344       21.5
# 3         3269       204.3        5486      342.9          435       27.2
# 4         3683       230.2        5771      360.7          363       22.7
#
# ...

# %%
off_def2012.tail()
# Out:
#                              Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 27        Seattle SeahawksSeattle          412       25.8         2579
# 28        St. Louis RamsSt. Louis          299       18.7         1714
# 29  Tampa Bay BuccaneersTampa Bay          389       24.3         1837
# 30      Tennessee TitansTennessee          330       20.6         1687
# 31  Washington RedskinsWashington          436       27.2         2709
#
#     Off RYds/G  Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  \
# 27       161.2         3031       189.4        5610      350.6          245
# 28       107.1         3550       221.9        5264      329.0          348
# 29       114.8         3983       248.9        5820      363.8          394
# 30       105.4         3323       207.7        5010      313.1          471
# 31       169.3         3422       213.9        6131      383.2          388
#
#     Def Pts/G  Def RushYds  Def RYds/G  Def PassYds  Def PYds/G  Def TotYds  \
# ...

# %% [markdown]
# ### Rename the Team column

# %%
teamnames = {'Arizona CardinalsArizona': 'Arizona Cardinals', 'Atlanta FalconsAtlanta': 'Atlanta Falcons', 
             'Baltimore RavensBaltimore': 'Baltimore Ravens', 'Buffalo BillsBuffalo': 'Buffalo Bills',
            'Carolina PanthersCarolina': 'Carolina Panthers', 'Chicago BearsChicago': 'Chicago Bears',
            'Cincinnati BengalsCincinnati': 'Cincinnati Bengals', 'Cleveland BrownsCleveland': 'Cleveland Browns',
            'Dallas CowboysDallas': 'Dallas Cowboys', 'Denver BroncosDenver': 'Denver Broncos', 
             'Detroit LionsDetroit': 'Detroit Lions', 'Green Bay PackersGreen Bay': 'Green Bay Packers',
            'Houston TexansHouston': 'Houston Texans', 'Indianapolis ColtsIndianapolis': 'Indianapolis Colts',
            'Jacksonville JaguarsJacksonville': 'Jacksonville Jaguars', 'Kansas City ChiefsKansas City': 'Kansas City Chiefs',
            'Miami DolphinsMiami': 'Miami Dolphins', 'Minnesota VikingsMinnesota': 'Minnesota Vikings', 
            'New England PatriotsNew England': 'New England Patriots', 'New Orleans SaintsNew Orleans': 'New Orleans Saints',
            'New York GiantsNY Giants': 'New York Giants', 'New York JetsNY Jets': 'New York Jets', 
            'Oakland RaidersOakland': 'Las Vegas Raiders', 'Philadelphia EaglesPhiladelphia': 'Philadelphia Eagles',
            'Pittsburgh SteelersPittsburgh': 'Pittsburgh Steelers', 'San Diego ChargersSan Diego': 'Los Angeles Chargers',
            'San Francisco 49ersSan Francisco': 'San Francisco 49ers', 'Seattle SeahawksSeattle': 'Seattle Seahawks',
            'St. Louis RamsSt. Louis': 'Los Angeles Rams', 
            'Tampa Bay BuccaneersTampa Bay': 'Tampa Bay Buccaneers', 'Tennessee TitansTennessee': 'Tennessee Titans',
            'Washington RedskinsWashington': 'Washington Commanders'}
off_def2012['Team'] = off_def2012['Team'].replace(teamnames)

# %%
off_def2012.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  Def Pts/G  \
# 0         3005       187.8        4209      263.1          357       22.3
# 1         4509       281.8        5906      369.1          299       18.7
# 2         3739       233.7        5640      352.5          344       21.5
# 3         3269       204.3        5486      342.9          435       27.2
# 4         3683       230.2        5771      360.7          363       22.7
#
#    Def RushYds  Def RYds/G  Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# ...

# %% [markdown]
# ### Put Dataset in Team Ascending Order

# %%
off_def2012 = off_def2012.sort_values("Team")

# %%
off_def2012.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  Def Pts/G  \
# 0         3005       187.8        4209      263.1          357       22.3
# 1         4509       281.8        5906      369.1          299       18.7
# 2         3739       233.7        5640      352.5          344       21.5
# 3         3269       204.3        5486      342.9          435       27.2
# 4         3683       230.2        5771      360.7          363       22.7
#
#    Def RushYds  Def RYds/G  Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# ...

# %% [markdown]
# ### Add year column

# %%
datayear12 = 2012
off_def2012['Year'] = datayear12

# %%
off_def2012.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  Def Pts/G  \
# 0         3005       187.8        4209      263.1          357       22.3
# 1         4509       281.8        5906      369.1          299       18.7
# 2         3739       233.7        5640      352.5          344       21.5
# 3         3269       204.3        5486      342.9          435       27.2
# 4         3683       230.2        5771      360.7          363       22.7
#
#    Def RushYds  Def RYds/G  Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  \
# ...

# %% [markdown]
# ### Import 2012 Win/Loss Dataset

# %%
wl2012 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_win_lose/NFL2012_wl.csv')

# %%
wl2012.head()
# Out:
#    Unnamed: 0               Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0           5  Arizona Cardinals     5      11    0        No     No  2012
# 1          30    Atlanta Falcons    13       3    0        No     No  2012
# 2          19   Baltimore Ravens    10       6    0       Yes    Yes  2012
# 3           7      Buffalo Bills     6      10    0        No     No  2012
# 4          10  Carolina Panthers     7       9    0        No     No  2012

# %% [markdown]
# ### Drop unnamed column

# %%
wl2012 = wl2012.iloc[:, 1:]

# %%
wl2012.head(32)
# Out:
#                      Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0       Arizona Cardinals     5      11    0        No     No  2012
# 1         Atlanta Falcons    13       3    0        No     No  2012
# 2        Baltimore Ravens    10       6    0       Yes    Yes  2012
# 3           Buffalo Bills     6      10    0        No     No  2012
# 4       Carolina Panthers     7       9    0        No     No  2012
# 5           Chicago Bears    10       6    0        No     No  2012
# 6      Cincinnati Bengals    10       6    0        No     No  2012
# 7        Cleveland Browns     5      11    0        No     No  2012
# 8          Dallas Cowboys     8       8    0        No     No  2012
# 9          Denver Broncos    13       3    0        No     No  2012
# 10          Detroit Lions     4      12    0        No     No  2012
# 11      Green Bay Packers    11       5    0        No     No  2012
# 12         Houston Texans    12       4    0        No     No  2012
# ...

# %%
off_def2012.head(32)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0       Arizona Cardinals          250       15.6         1204        75.2
# 1         Atlanta Falcons          419       26.2         1397        87.3
# 2        Baltimore Ravens          398       24.9         1901       118.8
# 3           Buffalo Bills          344       21.5         2217       138.6
# 4       Carolina Panthers          357       22.3         2088       130.5
# 5           Chicago Bears          375       23.4         1970       123.1
# 6      Cincinnati Bengals          391       24.4         1745       109.1
# 7        Cleveland Browns          302       18.9         1593        99.6
# 8          Dallas Cowboys          376       23.5         1265        79.1
# 9          Denver Broncos          481       30.1         1832       114.5
# 10          Detroit Lions          372       23.2         1613       100.8
# ...

# %% [markdown]
# ### Merge 2012 off/def data with 2012 w/l/sb data

# %%
nfl2012 = pd.merge(off_def2012, wl2012, on=['Team', 'Year'])

# %%
nfl2012.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Data for future use

# %%
nfl2012.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012.csv')

# %% [markdown]
# ## Import 2013 Offense & Defense Datasets

# %%
off2013 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2013_offense.csv')

# %%
def2013 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2013_defense.csv')

# %%
off2013.head()
# Out:
#    Unnamed: 0                       Team  2013 Off Tot Pts  2013 Off Pts/G  \
# 0          11   Arizona CardinalsArizona               379            23.7
# 1          13     Atlanta FalconsAtlanta               353            22.1
# 2          28  Baltimore RavensBaltimore               320            20.0
# 3          18       Buffalo BillsBuffalo               339            21.2
# 4          25  Carolina PanthersCarolina               366            22.9
#
#    2013 Off RushYds  2013 Off RYds/G  2013 Off PassYds  2013 Off PYds/G  \
# 0              1540             96.2              4002            250.1
# 1              1247             77.9              4243            265.2
# 2              1328             83.0              3590            224.4
# 3              2307            144.2              3103            193.9
# 4              2026            126.6              3043            190.2
#
#    2013 Off TotYds  2013 Off Yds/G
# 0             5542           346.4
# ...

# %%
def2013.head()
# Out:
#    Unnamed: 0                       Team  2013 Def Tot Pts  2013 Def Pts/G  \
# 0           5   Arizona CardinalsArizona               324            20.2
# 1          26     Atlanta FalconsAtlanta               443            27.7
# 2          11  Baltimore RavensBaltimore               352            22.0
# 3           9       Buffalo BillsBuffalo               388            24.2
# 4           1  Carolina PanthersCarolina               241            15.1
#
#    2013 Def RushYds  2013 Def RYds/G  2013 Def PassYds  2013 Def PYds/G  \
# 0              1351             84.4              3728            233.0
# 1              2173            135.8              3897            243.6
# 2              1687            105.4              3681            230.1
# 3              2063            128.9              3271            204.4
# 4              1391             86.9              3429            214.3
#
#    2013 Def TotYds  2013 Def Yds/G
# 0             5079           317.4
# ...

# %% [markdown]
# ### Drop unnamed column in both datasets

# %%
off2013 = off2013.iloc[:, 1:]

# %%
off2013.head()
# Out:
#                         Team  2013 Off Tot Pts  2013 Off Pts/G  \
# 0   Arizona CardinalsArizona               379            23.7
# 1     Atlanta FalconsAtlanta               353            22.1
# 2  Baltimore RavensBaltimore               320            20.0
# 3       Buffalo BillsBuffalo               339            21.2
# 4  Carolina PanthersCarolina               366            22.9
#
#    2013 Off RushYds  2013 Off RYds/G  2013 Off PassYds  2013 Off PYds/G  \
# 0              1540             96.2              4002            250.1
# 1              1247             77.9              4243            265.2
# 2              1328             83.0              3590            224.4
# 3              2307            144.2              3103            193.9
# 4              2026            126.6              3043            190.2
#
#    2013 Off TotYds  2013 Off Yds/G
# 0             5542           346.4
# 1             5490           343.1
# 2             4918           307.4
# ...

# %%
def2013 = def2013.iloc[:, 1:]

# %%
def2013.head()
# Out:
#                         Team  2013 Def Tot Pts  2013 Def Pts/G  \
# 0   Arizona CardinalsArizona               324            20.2
# 1     Atlanta FalconsAtlanta               443            27.7
# 2  Baltimore RavensBaltimore               352            22.0
# 3       Buffalo BillsBuffalo               388            24.2
# 4  Carolina PanthersCarolina               241            15.1
#
#    2013 Def RushYds  2013 Def RYds/G  2013 Def PassYds  2013 Def PYds/G  \
# 0              1351             84.4              3728            233.0
# 1              2173            135.8              3897            243.6
# 2              1687            105.4              3681            230.1
# 3              2063            128.9              3271            204.4
# 4              1391             86.9              3429            214.3
#
#    2013 Def TotYds  2013 Def Yds/G
# 0             5079           317.4
# 1             6070           379.4
# 2             5368           335.5
# ...

# %% [markdown]
# ### Rename Columns

# %%
offense2013 = off2013.rename(columns ={"2013 Off Tot Pts": "Off Tot/Pts", "2013 Off Pts/G": "Off Pts/G",
                                                     "2013 Off RushYds": "Off RushYds", "2013 Off RYds/G": "Off RYds/G",
                                                     "2013 Off PassYds": "Off PassYds", "2013 Off PYds/G": "Off PYds/G",
                                                     "2013 Off TotYds": "Off TotYds", "2013 Off Yds/G": "Off Yds/G"})

# %%
offense2013.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          379       23.7         1540        96.2
# 1     Atlanta FalconsAtlanta          353       22.1         1247        77.9
# 2  Baltimore RavensBaltimore          320       20.0         1328        83.0
# 3       Buffalo BillsBuffalo          339       21.2         2307       144.2
# 4  Carolina PanthersCarolina          366       22.9         2026       126.6
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G
# 0         4002       250.1        5542      346.4
# 1         4243       265.2        5490      343.1
# 2         3590       224.4        4918      307.4
# 3         3103       193.9        5410      338.1
# 4         3043       190.2        5069      316.8

# %%
defense2013 = def2013.rename(columns ={"2013 Def Tot Pts": "Def Tot/Pts", "2013 Def Pts/G": "Def Pts/G",
                                                     "2013 Def RushYds": "Def RushYds", "2013 Def RYds/G": "Def RYds/G",
                                                     "2013 Def PassYds": "Def PassYds", "2013 Def PYds/G": "Def PYds/G",
                                                     "2013 Def TotYds": "Def TotYds", "2013 Def Yds/G": "Def Yds/G"})

# %%
defense2013.head()
# Out:
#                         Team  Def Tot/Pts  Def Pts/G  Def RushYds  Def RYds/G  \
# 0   Arizona CardinalsArizona          324       20.2         1351        84.4
# 1     Atlanta FalconsAtlanta          443       27.7         2173       135.8
# 2  Baltimore RavensBaltimore          352       22.0         1687       105.4
# 3       Buffalo BillsBuffalo          388       24.2         2063       128.9
# 4  Carolina PanthersCarolina          241       15.1         1391        86.9
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# 0         3728       233.0        5079      317.4
# 1         3897       243.6        6070      379.4
# 2         3681       230.1        5368      335.5
# 3         3271       204.4        5334      333.4
# 4         3429       214.3        4820      301.2

# %% [markdown]
# ### Merge 2013 Offense & Defense Data

# %%
off_def2013 = pd.merge(offense2013, defense2013, on='Team')

# %%
off_def2013.head(32)
# Out:
#                                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0           Arizona CardinalsArizona          379       23.7         1540
# 1             Atlanta FalconsAtlanta          353       22.1         1247
# 2          Baltimore RavensBaltimore          320       20.0         1328
# 3               Buffalo BillsBuffalo          339       21.2         2307
# 4          Carolina PanthersCarolina          366       22.9         2026
# 5               Chicago BearsChicago          445       27.8         1828
# 6       Cincinnati BengalsCincinnati          430       26.9         1755
# 7          Cleveland BrownsCleveland          308       19.2         1383
# 8               Dallas CowboysDallas          439       27.4         1504
# 9               Denver BroncosDenver          606       37.9         1873
# 10              Detroit LionsDetroit          395       24.7         1792
# 11        Green Bay PackersGreen Bay          417       26.1         2136
# ...

# %% [markdown]
# ### Rename Teams to match incoming data

# %%
teamnames13 = {'Arizona CardinalsArizona': 'Arizona Cardinals', 'Atlanta FalconsAtlanta': 'Atlanta Falcons', 
             'Baltimore RavensBaltimore': 'Baltimore Ravens', 'Buffalo BillsBuffalo': 'Buffalo Bills',
            'Carolina PanthersCarolina': 'Carolina Panthers', 'Chicago BearsChicago': 'Chicago Bears',
            'Cincinnati BengalsCincinnati': 'Cincinnati Bengals', 'Cleveland BrownsCleveland': 'Cleveland Browns',
            'Dallas CowboysDallas': 'Dallas Cowboys', 'Denver BroncosDenver': 'Denver Broncos', 
             'Detroit LionsDetroit': 'Detroit Lions', 'Green Bay PackersGreen Bay': 'Green Bay Packers',
            'Houston TexansHouston': 'Houston Texans', 'Indianapolis ColtsIndianapolis': 'Indianapolis Colts',
            'Jacksonville JaguarsJacksonville': 'Jacksonville Jaguars', 'Kansas City ChiefsKansas City': 'Kansas City Chiefs',
            'Miami DolphinsMiami': 'Miami Dolphins', 'Minnesota VikingsMinnesota': 'Minnesota Vikings', 
            'New England PatriotsNew England': 'New England Patriots', 'New Orleans SaintsNew Orleans': 'New Orleans Saints',
            'New York GiantsNY Giants': 'New York Giants', 'New York JetsNY Jets': 'New York Jets', 
            'Oakland RaidersOakland': 'Las Vegas Raiders', 'Philadelphia EaglesPhiladelphia': 'Philadelphia Eagles',
            'Pittsburgh SteelersPittsburgh': 'Pittsburgh Steelers', 'San Diego ChargersSan Diego': 'Los Angeles Chargers',
            'San Francisco 49ersSan Francisco': 'San Francisco 49ers', 'Seattle SeahawksSeattle': 'Seattle Seahawks',
            'St. Louis RamsSt. Louis': 'Los Angeles Rams', 
            'Tampa Bay BuccaneersTampa Bay': 'Tampa Bay Buccaneers', 'Tennessee TitansTennessee': 'Tennessee Titans',
            'Washington RedskinsWashington': 'Washington Commanders'}
off_def2013['Team'] = off_def2013['Team'].replace(teamnames13)

# %%
off_def2013.head(32)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0       Arizona Cardinals          379       23.7         1540        96.2
# 1         Atlanta Falcons          353       22.1         1247        77.9
# 2        Baltimore Ravens          320       20.0         1328        83.0
# 3           Buffalo Bills          339       21.2         2307       144.2
# 4       Carolina Panthers          366       22.9         2026       126.6
# 5           Chicago Bears          445       27.8         1828       114.2
# 6      Cincinnati Bengals          430       26.9         1755       109.7
# 7        Cleveland Browns          308       19.2         1383        86.4
# 8          Dallas Cowboys          439       27.4         1504        94.0
# 9          Denver Broncos          606       37.9         1873       117.1
# 10          Detroit Lions          395       24.7         1792       112.0
# ...

# %% [markdown]
# ### Put Dataset in Team Ascending Order

# %%
off_def2013 = off_def2013.sort_values("Team")

# %%
off_def2013.head(32)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0       Arizona Cardinals          379       23.7         1540        96.2
# 1         Atlanta Falcons          353       22.1         1247        77.9
# 2        Baltimore Ravens          320       20.0         1328        83.0
# 3           Buffalo Bills          339       21.2         2307       144.2
# 4       Carolina Panthers          366       22.9         2026       126.6
# 5           Chicago Bears          445       27.8         1828       114.2
# 6      Cincinnati Bengals          430       26.9         1755       109.7
# 7        Cleveland Browns          308       19.2         1383        86.4
# 8          Dallas Cowboys          439       27.4         1504        94.0
# 9          Denver Broncos          606       37.9         1873       117.1
# 10          Detroit Lions          395       24.7         1792       112.0
# ...

# %% [markdown]
# ### Add year column

# %%
datayear13 = 2013
off_def2013['Year'] = datayear13

# %%
off_def2013.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          379       23.7         1540        96.2
# 1    Atlanta Falcons          353       22.1         1247        77.9
# 2   Baltimore Ravens          320       20.0         1328        83.0
# 3      Buffalo Bills          339       21.2         2307       144.2
# 4  Carolina Panthers          366       22.9         2026       126.6
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  Def Pts/G  \
# 0         4002       250.1        5542      346.4          324       20.2
# 1         4243       265.2        5490      343.1          443       27.7
# 2         3590       224.4        4918      307.4          352       22.0
# 3         3103       193.9        5410      338.1          388       24.2
# 4         3043       190.2        5069      316.8          241       15.1
#
#    Def RushYds  Def RYds/G  Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  \
# ...

# %% [markdown]
# ### Import 2013 Win/Loss Datset

# %%
wl2013 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_win_lose/NFL_2013_wl.csv')

# %%
wl2013.head()
# Out:
#    Unnamed: 0               Team  Wins  Losses  Tie Superbowl SB Win
# 0          21  Arizona Cardinals    10       6    0        No     No
# 1           2    Atlanta Falcons     4      12    0        No     No
# 2          13   Baltimore Ravens     8       8    0        No     No
# 3           8      Buffalo Bills     6      10    0        No     No
# 4          27  Carolina Panthers    12       4    0        No     No

# %% [markdown]
# ### Drop Unnamed Column

# %%
wl2013 = wl2013.iloc[:, 1:]

# %%
wl2013.head()
# Out:
#                 Team  Wins  Losses  Tie Superbowl SB Win
# 0  Arizona Cardinals    10       6    0        No     No
# 1    Atlanta Falcons     4      12    0        No     No
# 2   Baltimore Ravens     8       8    0        No     No
# 3      Buffalo Bills     6      10    0        No     No
# 4  Carolina Panthers    12       4    0        No     No

# %% [markdown]
# ### Add Year column

# %%
wl13 = 2013
wl2013['Year'] = wl13

# %%
wl2013.head()
# Out:
#                 Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0  Arizona Cardinals    10       6    0        No     No  2013
# 1    Atlanta Falcons     4      12    0        No     No  2013
# 2   Baltimore Ravens     8       8    0        No     No  2013
# 3      Buffalo Bills     6      10    0        No     No  2013
# 4  Carolina Panthers    12       4    0        No     No  2013

# %% [markdown]
# ### Merge 2013 off/def data with 2013 w/l/sb data

# %%
nfl2013 = pd.merge(off_def2013, wl2013, on=['Team', 'Year'])

# %%
nfl2013.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          379       23.7         1540        96.2
# 1    Atlanta Falcons          353       22.1         1247        77.9
# 2   Baltimore Ravens          320       20.0         1328        83.0
# 3      Buffalo Bills          339       21.2         2307       144.2
# 4  Carolina Panthers          366       22.9         2026       126.6
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         4002       250.1        5542      346.4          324  ...
# 1         4243       265.2        5490      343.1          443  ...
# 2         3590       224.4        4918      307.4          352  ...
# 3         3103       193.9        5410      338.1          388  ...
# 4         3043       190.2        5069      316.8          241  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2013.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2013complete.csv')

# %% [markdown]
# ## Merge 2012 & 2013 together

# %%
nfl2012_2013 = pd.concat([nfl2012, nfl2013], axis=0, join='outer', ignore_index='True')

# %%
nfl2012_2013.head(64)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0       Arizona Cardinals          250       15.6         1204        75.2
# 1         Atlanta Falcons          419       26.2         1397        87.3
# 2        Baltimore Ravens          398       24.9         1901       118.8
# 3           Buffalo Bills          344       21.5         2217       138.6
# 4       Carolina Panthers          357       22.3         2088       130.5
# ..                    ...          ...        ...          ...         ...
# 59    San Francisco 49ers          406       25.4         2201       137.6
# 60       Seattle Seahawks          417       26.1         2188       136.8
# 61   Tampa Bay Buccaneers          288       18.0         1612       100.8
# 62       Tennessee Titans          362       22.6         1894       118.4
# 63  Washington Commanders          334       20.9         2164       135.2
#
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2012_2013.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2013merge.csv')

# %% [markdown]
# ## Import 2014 Offense & Defense Data

# %%
off2014 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2014_offense.csv')

# %%
def2014 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2014_defense.csv')

# %%
off2014.head()
# Out:
#    Unnamed: 0                       Team  2014 Off Tot Pts  2014 Off Pts/G  \
# 0          23   Arizona CardinalsArizona               310            19.4
# 1           7     Atlanta FalconsAtlanta               381            23.8
# 2          11  Baltimore RavensBaltimore               409            25.6
# 3          25       Buffalo BillsBuffalo               343            21.4
# 4          15  Carolina PanthersCarolina               339            21.2
#
#    2014 Off RushYds  2014 Off RYds/G  2014 Off PassYds  2014 Off PYds/G  \
# 0              1308             81.8              3808            238.0
# 1              1498             93.6              4553            284.6
# 2              2019            126.2              3819            238.7
# 3              1482             92.6              3614            225.9
# 4              2036            127.2              3511            219.4
#
#    2014 Off TotYds  2014 Off Yds/G
# 0             5116           319.8
# ...

# %%
def2014.head()
# Out:
#    Unnamed: 0                       Team  2014 Def Tot Pts  2014 Def Pts/G  \
# 0          23   Arizona CardinalsArizona               299            18.7
# 1          31     Atlanta FalconsAtlanta               417            26.1
# 2           7  Baltimore RavensBaltimore               302            18.9
# 3           3       Buffalo BillsBuffalo               289            18.1
# 4           9  Carolina PanthersCarolina               374            23.4
#
#    2014 Def RushYds  2014 Def RYds/G  2014 Def PassYds  2014 Def PYds/G  \
# 0              1739            108.7              4152            259.5
# 1              1894            118.4              4478            279.9
# 2              1412             88.2              3979            248.7
# 3              1703            106.4              3292            205.8
# 4              1792            112.0              3645            227.8
#
#    2014 Def TotYds  2014 Def Yds/G
# 0             5891           368.2
# ...

# %% [markdown]
# ### Drop unnamed column in both datasets

# %%
off2014 = off2014.iloc[:, 1:]

# %%
off2014.head()
# Out:
#                         Team  2014 Off Tot Pts  2014 Off Pts/G  \
# 0   Arizona CardinalsArizona               310            19.4
# 1     Atlanta FalconsAtlanta               381            23.8
# 2  Baltimore RavensBaltimore               409            25.6
# 3       Buffalo BillsBuffalo               343            21.4
# 4  Carolina PanthersCarolina               339            21.2
#
#    2014 Off RushYds  2014 Off RYds/G  2014 Off PassYds  2014 Off PYds/G  \
# 0              1308             81.8              3808            238.0
# 1              1498             93.6              4553            284.6
# 2              2019            126.2              3819            238.7
# 3              1482             92.6              3614            225.9
# 4              2036            127.2              3511            219.4
#
#    2014 Off TotYds  2014 Off Yds/G
# 0             5116           319.8
# 1             6051           378.2
# 2             5838           364.9
# ...

# %%
def2014 = def2014.iloc[:, 1:]

# %%
def2014.head()
# Out:
#                         Team  2014 Def Tot Pts  2014 Def Pts/G  \
# 0   Arizona CardinalsArizona               299            18.7
# 1     Atlanta FalconsAtlanta               417            26.1
# 2  Baltimore RavensBaltimore               302            18.9
# 3       Buffalo BillsBuffalo               289            18.1
# 4  Carolina PanthersCarolina               374            23.4
#
#    2014 Def RushYds  2014 Def RYds/G  2014 Def PassYds  2014 Def PYds/G  \
# 0              1739            108.7              4152            259.5
# 1              1894            118.4              4478            279.9
# 2              1412             88.2              3979            248.7
# 3              1703            106.4              3292            205.8
# 4              1792            112.0              3645            227.8
#
#    2014 Def TotYds  2014 Def Yds/G
# 0             5891           368.2
# 1             6372           398.2
# 2             5391           336.9
# ...

# %% [markdown]
# ### Rename Columns

# %%
offense2014 = off2014.rename(columns ={"2014 Off Tot Pts": "Off Tot/Pts", "2014 Off Pts/G": "Off Pts/G",
                                                     "2014 Off RushYds": "Off RushYds", "2014 Off RYds/G": "Off RYds/G",
                                                     "2014 Off PassYds": "Off PassYds", "2014 Off PYds/G": "Off PYds/G",
                                                     "2014 Off TotYds": "Off TotYds", "2014 Off Yds/G": "Off Yds/G"})

# %%
offense2014.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          310       19.4         1308        81.8
# 1     Atlanta FalconsAtlanta          381       23.8         1498        93.6
# 2  Baltimore RavensBaltimore          409       25.6         2019       126.2
# 3       Buffalo BillsBuffalo          343       21.4         1482        92.6
# 4  Carolina PanthersCarolina          339       21.2         2036       127.2
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G
# 0         3808       238.0        5116      319.8
# 1         4553       284.6        6051      378.2
# 2         3819       238.7        5838      364.9
# 3         3614       225.9        5096      318.5
# 4         3511       219.4        5547      346.7

# %%
defense2014 = def2014.rename(columns ={"2014 Def Tot Pts": "Def Tot/Pts", "2014 Def Pts/G": "Def Pts/G",
                                                     "2014 Def RushYds": "Def RushYds", "2014 Def RYds/G": "Def RYds/G",
                                                     "2014 Def PassYds": "Def PassYds", "2014 Def PYds/G": "Def PYds/G",
                                                     "2014 Def TotYds": "Def TotYds", "2014 Def Yds/G": "Def Yds/G"})

# %%
defense2014.head()
# Out:
#                         Team  Def Tot/Pts  Def Pts/G  Def RushYds  Def RYds/G  \
# 0   Arizona CardinalsArizona          299       18.7         1739       108.7
# 1     Atlanta FalconsAtlanta          417       26.1         1894       118.4
# 2  Baltimore RavensBaltimore          302       18.9         1412        88.2
# 3       Buffalo BillsBuffalo          289       18.1         1703       106.4
# 4  Carolina PanthersCarolina          374       23.4         1792       112.0
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# 0         4152       259.5        5891      368.2
# 1         4478       279.9        6372      398.2
# 2         3979       248.7        5391      336.9
# 3         3292       205.8        4995      312.2
# 4         3645       227.8        5437      339.8

# %% [markdown]
# ### Merge 2014 Offense & Defense Data

# %%
off_def2014 = pd.merge(offense2014, defense2014, on='Team')

# %%
off_def2014.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          310       19.4         1308        81.8
# 1     Atlanta FalconsAtlanta          381       23.8         1498        93.6
# 2  Baltimore RavensBaltimore          409       25.6         2019       126.2
# 3       Buffalo BillsBuffalo          343       21.4         1482        92.6
# 4  Carolina PanthersCarolina          339       21.2         2036       127.2
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  Def Pts/G  \
# 0         3808       238.0        5116      319.8          299       18.7
# 1         4553       284.6        6051      378.2          417       26.1
# 2         3819       238.7        5838      364.9          302       18.9
# 3         3614       225.9        5096      318.5          289       18.1
# 4         3511       219.4        5547      346.7          374       23.4
#
# ...

# %% [markdown]
# ### Rename Teams to match incoming data

# %%
teamnames14 = {'Arizona CardinalsArizona': 'Arizona Cardinals', 'Atlanta FalconsAtlanta': 'Atlanta Falcons', 
             'Baltimore RavensBaltimore': 'Baltimore Ravens', 'Buffalo BillsBuffalo': 'Buffalo Bills',
            'Carolina PanthersCarolina': 'Carolina Panthers', 'Chicago BearsChicago': 'Chicago Bears',
            'Cincinnati BengalsCincinnati': 'Cincinnati Bengals', 'Cleveland BrownsCleveland': 'Cleveland Browns',
            'Dallas CowboysDallas': 'Dallas Cowboys', 'Denver BroncosDenver': 'Denver Broncos', 
             'Detroit LionsDetroit': 'Detroit Lions', 'Green Bay PackersGreen Bay': 'Green Bay Packers',
            'Houston TexansHouston': 'Houston Texans', 'Indianapolis ColtsIndianapolis': 'Indianapolis Colts',
            'Jacksonville JaguarsJacksonville': 'Jacksonville Jaguars', 'Kansas City ChiefsKansas City': 'Kansas City Chiefs',
            'Miami DolphinsMiami': 'Miami Dolphins', 'Minnesota VikingsMinnesota': 'Minnesota Vikings', 
            'New England PatriotsNew England': 'New England Patriots', 'New Orleans SaintsNew Orleans': 'New Orleans Saints',
            'New York GiantsNY Giants': 'New York Giants', 'New York JetsNY Jets': 'New York Jets', 
            'Oakland RaidersOakland': 'Las Vegas Raiders', 'Philadelphia EaglesPhiladelphia': 'Philadelphia Eagles',
            'Pittsburgh SteelersPittsburgh': 'Pittsburgh Steelers', 'San Diego ChargersSan Diego': 'Los Angeles Chargers',
            'San Francisco 49ersSan Francisco': 'San Francisco 49ers', 'Seattle SeahawksSeattle': 'Seattle Seahawks',
            'St. Louis RamsSt. Louis': 'Los Angeles Rams', 
            'Tampa Bay BuccaneersTampa Bay': 'Tampa Bay Buccaneers', 'Tennessee TitansTennessee': 'Tennessee Titans',
            'Washington RedskinsWashington': 'Washington Commanders'}
off_def2014['Team'] = off_def2014['Team'].replace(teamnames14)

# %%
off_def2014.head(32)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0       Arizona Cardinals          310       19.4         1308        81.8
# 1         Atlanta Falcons          381       23.8         1498        93.6
# 2        Baltimore Ravens          409       25.6         2019       126.2
# 3           Buffalo Bills          343       21.4         1482        92.6
# 4       Carolina Panthers          339       21.2         2036       127.2
# 5           Chicago Bears          319       19.9         1441        90.1
# 6      Cincinnati Bengals          365       22.8         2147       134.2
# 7        Cleveland Browns          299       18.7         1728       108.0
# 8          Dallas Cowboys          467       29.2         2354       147.1
# 9          Denver Broncos          482       30.1         1785       111.6
# 10          Detroit Lions          321       20.1         1422        88.9
# ...

# %% [markdown]
# ### Put Dataset in Team Ascending Order

# %%
off_def2014 = off_def2014.sort_values("Team")

# %%
off_def2014.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          310       19.4         1308        81.8
# 1    Atlanta Falcons          381       23.8         1498        93.6
# 2   Baltimore Ravens          409       25.6         2019       126.2
# 3      Buffalo Bills          343       21.4         1482        92.6
# 4  Carolina Panthers          339       21.2         2036       127.2
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  Def Pts/G  \
# 0         3808       238.0        5116      319.8          299       18.7
# 1         4553       284.6        6051      378.2          417       26.1
# 2         3819       238.7        5838      364.9          302       18.9
# 3         3614       225.9        5096      318.5          289       18.1
# 4         3511       219.4        5547      346.7          374       23.4
#
#    Def RushYds  Def RYds/G  Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# ...

# %%
off_def2014.tail(16)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 22      Las Vegas Raiders          253       15.8         1240        77.5
# 25   Los Angeles Chargers          348       21.8         1367        85.4
# 28       Los Angeles Rams          324       20.2         1635       102.2
# 16         Miami Dolphins          388       24.2         1872       117.0
# 17      Minnesota Vikings          325       20.3         1804       112.8
# 18   New England Patriots          468       29.2         1727       107.9
# 19     New Orleans Saints          401       25.1         1818       113.6
# 20        New York Giants          380       23.8         1603       100.2
# 21          New York Jets          283       17.7         2280       142.5
# 23    Philadelphia Eagles          474       29.6         1992       124.5
# 24    Pittsburgh Steelers          436       27.2         1752       109.5
# ...

# %% [markdown]
# ## Import 2014 Win/Loss Dataset

# %%
wl2014 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_win_lose/NFL_2014_wl.csv')

# %%
wl2014.head()
# Out:
#    Unnamed: 0               Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0          23  Arizona Cardinals    11       5    0        No     No  2014
# 1           7    Atlanta Falcons     6      10    0        No     No  2014
# 2          20   Baltimore Ravens    10       6    0        No     No  2014
# 3          16      Buffalo Bills     9       7    0        No     No  2014
# 4          10  Carolina Panthers     7       8    1        No     No  2014

# %% [markdown]
# ### Drop unnamed column

# %%
wl2014 = wl2014.iloc[:, 1:]

# %%
wl2014.head()
# Out:
#                 Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0  Arizona Cardinals    11       5    0        No     No  2014
# 1    Atlanta Falcons     6      10    0        No     No  2014
# 2   Baltimore Ravens    10       6    0        No     No  2014
# 3      Buffalo Bills     9       7    0        No     No  2014
# 4  Carolina Panthers     7       8    1        No     No  2014

# %% [markdown]
# ### Merge 2014 off/def data with w/l/sb data

# %%
nfl2014 = pd.merge(off_def2014, wl2014, on="Team")

# %%
nfl2014.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          310       19.4         1308        81.8
# 1    Atlanta Falcons          381       23.8         1498        93.6
# 2   Baltimore Ravens          409       25.6         2019       126.2
# 3      Buffalo Bills          343       21.4         1482        92.6
# 4  Carolina Panthers          339       21.2         2036       127.2
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3808       238.0        5116      319.8          299  ...
# 1         4553       284.6        6051      378.2          417  ...
# 2         3819       238.7        5838      364.9          302  ...
# 3         3614       225.9        5096      318.5          289  ...
# 4         3511       219.4        5547      346.7          374  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2014.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2014complete.csv')

# %% [markdown]
# ### Merge 2012-2014 Data

# %%
nfl2012_2014 = pd.concat([nfl2012_2013, nfl2014], axis=0, join='outer', ignore_index='True')

# %%
nfl2012_2014.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
nfl2012_2014.tail()
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 91    San Francisco 49ers          306       19.1         2176       136.0
# 92       Seattle Seahawks          394       24.6         2762       172.6
# 93   Tampa Bay Buccaneers          277       17.3         1375        85.9
# 94       Tennessee Titans          254       15.9         1447        90.4
# 95  Washington Commanders          301       18.8         1691       105.7
#
#     Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 91         3063       191.4        5239      327.4          340  ...
# 92         3250       203.1        6012      375.8          254  ...
# 93         3297       206.1        4672      292.0          410  ...
# 94         3412       213.2        4859      303.7          438  ...
# 95         4047       252.9        5738      358.6          438  ...
#
#     Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset for future use

# %%
nfl2012_2014.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2014merge.csv')

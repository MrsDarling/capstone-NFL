# %% [markdown]
# # Merge Years 2012-2022

# %% [markdown]
# ### Import pandas package

# %%
import pandas as pd

# %% [markdown]
# ## Import all datasets for final merge

# %%
nfl2012_2021 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2021merge.csv')
off2022 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2022_offense.csv')
def2022 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2022_defense.csv')
wl2022 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_win_lose/NFL_2022_wl.csv')

# %%
nfl2012_2021.head()
# Out:
#    Unnamed: 0               Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0           0  Arizona Cardinals          250       15.6         1204
# 1           1    Atlanta Falcons          419       26.2         1397
# 2           2   Baltimore Ravens          398       24.9         1901
# 3           3      Buffalo Bills          344       21.5         2217
# 4           4  Carolina Panthers          357       22.3         2088
#
#    Off RYds/G  Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  ...  \
# 0        75.2         3005       187.8        4209      263.1  ...
# 1        87.3         4509       281.8        5906      369.1  ...
# 2       118.8         3739       233.7        5640      352.5  ...
# 3       138.6         3269       204.3        5486      342.9  ...
# 4       130.5         3683       230.2        5771      360.7  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
off2022.head()
# Out:
#    Unnamed: 0                       Team  Tot/Pts  2022 Off Pts/G  \
# 0          21   Arizona CardinalsArizona      340            20.0
# 1          23     Atlanta FalconsAtlanta      365            21.5
# 2          15  Baltimore RavensBaltimore      350            20.6
# 3           1       Buffalo BillsBuffalo      455            28.4
# 4          28  Carolina PanthersCarolina      347            20.4
#
#    2022 Off RushYds  2022 Off RYds/G  2022 Off PassYds  2022 Off PYds/G  \
# 0              1873            110.2              3626            213.3
# 1              2718            159.9              2699            158.8
# 2              2720            160.0              3040            178.8
# 3              2232            139.5              4129            258.1
# 4              2210            130.0              2996            176.2
#
#    2022 Off TotYds  2022 Off Yds/G
# 0             5499           323.5
# 1             5417           318.6
# ...

# %%
def2022.head()
# Out:
#    Unnamed: 0                       Team  2022 Def Tot/Pts  2022 Def Pts/G  \
# 0          20   Arizona CardinalsArizona               449            26.4
# 1          26     Atlanta FalconsAtlanta               386            22.7
# 2           8  Baltimore RavensBaltimore               315            18.5
# 3           5       Buffalo BillsBuffalo               286            17.9
# 4          21  Carolina PanthersCarolina               374            22.0
#
#    2022 Def RushYds  2022 Def RYds/G  2022 Def PassYds  2022 Def PYds/G  \
# 0              2016            118.6              3915            230.3
# 1              2214            130.2              3942            231.9
# 2              1566             92.1              3947            232.2
# 3              1673            104.6              3433            214.6
# 4              2085            122.6              3868            227.5
#
#    2022 Def TotYds  2022 Def Yds/G
# 0             5931           348.9
# ...

# %%
wl2022.head()
# Out:
#    Unnamed: 0               Team  Wins  Losses Superbowl SB Wins  Year
# 0           0  Arizona Cardinals     4      13        No      No  2022
# 1           1    Atlanta Falcons     7      10        No      No  2022
# 2           2   Baltimore Ravens    10       7        No      No  2022
# 3           3      Buffalo Bills    13       3        No      No  2022
# 4           4  Carolina Panthers     7      10        No      No  2022

# %% [markdown]
# ### Drop unnamed column in all datasets

# %%
nfl2012_2021 = nfl2012_2021.iloc[:, 1:]
off2022 = off2022.iloc[:, 1:]
def2022 = def2022.iloc[:, 1:]
wl2022 = wl2022.iloc[:, 1:]

# %%
nfl2012_2021.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
off2022.head()
# Out:
#                         Team  Tot/Pts  2022 Off Pts/G  2022 Off RushYds  \
# 0   Arizona CardinalsArizona      340            20.0              1873
# 1     Atlanta FalconsAtlanta      365            21.5              2718
# 2  Baltimore RavensBaltimore      350            20.6              2720
# 3       Buffalo BillsBuffalo      455            28.4              2232
# 4  Carolina PanthersCarolina      347            20.4              2210
#
#    2022 Off RYds/G  2022 Off PassYds  2022 Off PYds/G  2022 Off TotYds  \
# 0            110.2              3626            213.3             5499
# 1            159.9              2699            158.8             5417
# 2            160.0              3040            178.8             5760
# 3            139.5              4129            258.1             6361
# 4            130.0              2996            176.2             5206
#
#    2022 Off Yds/G
# 0           323.5
# 1           318.6
# 2           338.8
# 3           397.6
# ...

# %%
def2022.head()
# Out:
#                         Team  2022 Def Tot/Pts  2022 Def Pts/G  \
# 0   Arizona CardinalsArizona               449            26.4
# 1     Atlanta FalconsAtlanta               386            22.7
# 2  Baltimore RavensBaltimore               315            18.5
# 3       Buffalo BillsBuffalo               286            17.9
# 4  Carolina PanthersCarolina               374            22.0
#
#    2022 Def RushYds  2022 Def RYds/G  2022 Def PassYds  2022 Def PYds/G  \
# 0              2016            118.6              3915            230.3
# 1              2214            130.2              3942            231.9
# 2              1566             92.1              3947            232.2
# 3              1673            104.6              3433            214.6
# 4              2085            122.6              3868            227.5
#
#    2022 Def TotYds  2022 Def Yds/G
# 0             5931           348.9
# 1             6156           362.1
# 2             5513           324.3
# ...

# %%
wl2022.head()
# Out:
#                 Team  Wins  Losses Superbowl SB Wins  Year
# 0  Arizona Cardinals     4      13        No      No  2022
# 1    Atlanta Falcons     7      10        No      No  2022
# 2   Baltimore Ravens    10       7        No      No  2022
# 3      Buffalo Bills    13       3        No      No  2022
# 4  Carolina Panthers     7      10        No      No  2022

# %% [markdown]
# ### Rename columns in off/def/sb dataset

# %%
offense2022 = off2022.rename(columns ={"Tot/Pts": "Off Tot/Pts", "2022 Off Pts/G": "Off Pts/G",
                                                     "2022 Off RushYds": "Off RushYds", "2022 Off RYds/G": "Off RYds/G",
                                                     "2022 Off PassYds": "Off PassYds", "2022 Off PYds/G": "Off PYds/G",
                                                     "2022 Off TotYds": "Off TotYds", "2022 Off Yds/G": "Off Yds/G"})
defense2022 = def2022.rename(columns ={"2022 Def Tot/Pts": "Def Tot/Pts", "2022 Def Pts/G": "Def Pts/G",
                                                     "2022 Def RushYds": "Def RushYds", "2022 Def RYds/G": "Def RYds/G",
                                                     "2022 Def PassYds": "Def PassYds", "2022 Def PYds/G": "Def PYds/G",
                                                     "2022 Def TotYds": "Def TotYds", "2022 Def Yds/G": "Def Yds/G"})
winloss2022 = wl2022.rename(columns ={"SB Wins": "SB Win"})

# %%
offense2022.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          340       20.0         1873       110.2
# 1     Atlanta FalconsAtlanta          365       21.5         2718       159.9
# 2  Baltimore RavensBaltimore          350       20.6         2720       160.0
# 3       Buffalo BillsBuffalo          455       28.4         2232       139.5
# 4  Carolina PanthersCarolina          347       20.4         2210       130.0
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G
# 0         3626       213.3        5499      323.5
# 1         2699       158.8        5417      318.6
# 2         3040       178.8        5760      338.8
# 3         4129       258.1        6361      397.6
# 4         2996       176.2        5206      306.2

# %%
defense2022.head()
# Out:
#                         Team  Def Tot/Pts  Def Pts/G  Def RushYds  Def RYds/G  \
# 0   Arizona CardinalsArizona          449       26.4         2016       118.6
# 1     Atlanta FalconsAtlanta          386       22.7         2214       130.2
# 2  Baltimore RavensBaltimore          315       18.5         1566        92.1
# 3       Buffalo BillsBuffalo          286       17.9         1673       104.6
# 4  Carolina PanthersCarolina          374       22.0         2085       122.6
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# 0         3915       230.3        5931      348.9
# 1         3942       231.9        6156      362.1
# 2         3947       232.2        5513      324.3
# 3         3433       214.6        5106      319.1
# 4         3868       227.5        5953      350.2

# %% [markdown]
# ### Merge Offense and Defense Data

# %%
off_def2022 = pd.merge(offense2022, defense2022, on='Team')

# %%
off_def2022.head(32)
# Out:
#                                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0           Arizona CardinalsArizona          340       20.0         1873
# 1             Atlanta FalconsAtlanta          365       21.5         2718
# 2          Baltimore RavensBaltimore          350       20.6         2720
# 3               Buffalo BillsBuffalo          455       28.4         2232
# 4          Carolina PanthersCarolina          347       20.4         2210
# 5               Chicago BearsChicago          326       19.2         3014
# 6       Cincinnati BengalsCincinnati          418       26.1         1528
# 7          Cleveland BrownsCleveland          361       21.2         2490
# 8               Dallas CowboysDallas          467       27.5         2298
# 9               Denver BroncosDenver          287       16.9         1935
# 10              Detroit LionsDetroit          453       26.6         2179
# 11        Green Bay PackersGreen Bay          370       21.8         2113
# ...

# %% [markdown]
# ### Rename Teams to match merge data

# %%
teamnames22 = {'Arizona CardinalsArizona': 'Arizona Cardinals', 'Atlanta FalconsAtlanta': 'Atlanta Falcons', 
             'Baltimore RavensBaltimore': 'Baltimore Ravens', 'Buffalo BillsBuffalo': 'Buffalo Bills',
            'Carolina PanthersCarolina': 'Carolina Panthers', 'Chicago BearsChicago': 'Chicago Bears',
            'Cincinnati BengalsCincinnati': 'Cincinnati Bengals', 'Cleveland BrownsCleveland': 'Cleveland Browns',
            'Dallas CowboysDallas': 'Dallas Cowboys', 'Denver BroncosDenver': 'Denver Broncos', 
             'Detroit LionsDetroit': 'Detroit Lions', 'Green Bay PackersGreen Bay': 'Green Bay Packers',
            'Houston TexansHouston': 'Houston Texans', 'Indianapolis ColtsIndianapolis': 'Indianapolis Colts',
            'Jacksonville JaguarsJacksonville': 'Jacksonville Jaguars', 'Kansas City ChiefsKansas City': 'Kansas City Chiefs',
            'Los Angeles ChargersLA Chargers': 'Los Angeles Chargers', 'Los Angeles RamsLA Rams': 'Los Angeles Rams',
            'Miami DolphinsMiami': 'Miami Dolphins', 'Minnesota VikingsMinnesota': 'Minnesota Vikings', 
            'New England PatriotsNew England': 'New England Patriots', 'New Orleans SaintsNew Orleans': 'New Orleans Saints',
            'New York GiantsNY Giants': 'New York Giants', 'New York JetsNY Jets': 'New York Jets', 
            'Las Vegas RaidersLas Vegas': 'Las Vegas Raiders', 'Philadelphia EaglesPhiladelphia': 'Philadelphia Eagles',
            'Pittsburgh SteelersPittsburgh': 'Pittsburgh Steelers',
            'San Francisco 49ersSan Francisco': 'San Francisco 49ers', 'Seattle SeahawksSeattle': 'Seattle Seahawks', 
            'Tampa Bay BuccaneersTampa Bay': 'Tampa Bay Buccaneers', 'Tennessee TitansTennessee': 'Tennessee Titans',
            'Washington CommandersWashington': 'Washington Commanders'}
off_def2022['Team'] = off_def2022['Team'].replace(teamnames22)

# %%
off_def2022.tail(16)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 16      Las Vegas Raiders          395       23.2         2059       121.1
# 17   Los Angeles Chargers          391       23.0         1524        89.6
# 18       Los Angeles Rams          307       18.1         1661        97.7
# 19         Miami Dolphins          397       23.4         1686        99.2
# 20      Minnesota Vikings          424       24.9         1661        97.7
# 21   New England Patriots          364       21.4         1812       106.6
# 22     New Orleans Saints          330       19.4         1982       116.6
# 23        New York Giants          365       21.5         2519       148.2
# 24          New York Jets          296       17.4         1686        99.2
# 25    Philadelphia Eagles          477       28.1         2509       147.6
# 26    Pittsburgh Steelers          308       18.1         2073       121.9
# ...

# %% [markdown]
# ### Put Dataset in Team Ascending Order

# %%
off_def2022 = off_def2022.sort_values("Team")

# %%
off_def2022.tail(16)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 16      Las Vegas Raiders          395       23.2         2059       121.1
# 17   Los Angeles Chargers          391       23.0         1524        89.6
# 18       Los Angeles Rams          307       18.1         1661        97.7
# 19         Miami Dolphins          397       23.4         1686        99.2
# 20      Minnesota Vikings          424       24.9         1661        97.7
# 21   New England Patriots          364       21.4         1812       106.6
# 22     New Orleans Saints          330       19.4         1982       116.6
# 23        New York Giants          365       21.5         2519       148.2
# 24          New York Jets          296       17.4         1686        99.2
# 25    Philadelphia Eagles          477       28.1         2509       147.6
# 26    Pittsburgh Steelers          308       18.1         2073       121.9
# ...

# %% [markdown]
# ### Merge with Win/Loss Data

# %%
nfl2022 = pd.merge(off_def2022, winloss2022, on="Team")

# %%
nfl2022.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          340       20.0         1873       110.2
# 1    Atlanta Falcons          365       21.5         2718       159.9
# 2   Baltimore Ravens          350       20.6         2720       160.0
# 3      Buffalo Bills          455       28.4         2232       139.5
# 4  Carolina Panthers          347       20.4         2210       130.0
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3626       213.3        5499      323.5          449  ...
# 1         2699       158.8        5417      318.6          386  ...
# 2         3040       178.8        5760      338.8          315  ...
# 3         4129       258.1        6361      397.6          286  ...
# 4         2996       176.2        5206      306.2          374  ...
#
#    Def RYds/G  Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Wins  Losses  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2022.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2022complete.csv')

# %% [markdown]
# ### Merge 2012-2022 Data

# %%
nfl2012_2022 = pd.concat([nfl2012_2021, nfl2022], axis=0, join='outer', ignore_index='True')

# %%
nfl2012_2022.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
nfl2012_2022.tail()
# Out:
#                       Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 346    San Francisco 49ers          450       26.5         2360       138.8
# 347       Seattle Seahawks          407       23.9         2042       120.1
# 348   Tampa Bay Buccaneers          313       18.4         1308        76.9
# 349       Tennessee Titans          298       17.5         2131       125.4
# 350  Washington Commanders          321       18.9         2143       126.1
#
#      Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 346         3856       226.8        6216      365.6          277  ...
# 347         3934       231.4        5976      351.5          401  ...
# 348         4586       269.8        5894      346.7          358  ...
# 349         2914       171.4        5045      296.8          359  ...
# 350         3472       204.2        5615      330.3          343  ...
#
#      Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for analysis

# %%
nfl2012_2022.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2022merge.csv')

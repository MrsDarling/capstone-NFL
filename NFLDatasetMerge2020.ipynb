# %% [markdown]
# # Merge Years 2012-2020

# %% [markdown]
# ### Import pandas package

# %%
import pandas as pd

# %% [markdown]
# ## Import all datasets needed for merge

# %%
nfl2012_2019 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2019merge.csv')
off2020 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2020_offense.csv')
def2020 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_off_def/NFL2020_defense.csv')
wl2020 = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_win_lose/NFL_2020_wl.csv')

# %%
nfl2012_2019.head()
# Out:
#    Unnamed: 0               Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0           0  Arizona Cardinals          250       15.6         1204
# 1           1    Atlanta Falcons          419       26.2         1397
# 2           2   Baltimore Ravens          398       24.9         1901
# 3           3      Buffalo Bills          344       21.5         2217
# 4           4  Carolina Panthers          357       22.3         2088
#
#    Off RYds/G  Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  ...  \
# 0        75.2         3005       187.8        4209      263.1  ...
# 1        87.3         4509       281.8        5906      369.1  ...
# 2       118.8         3739       233.7        5640      352.5  ...
# 3       138.6         3269       204.3        5486      342.9  ...
# 4       130.5         3683       230.2        5771      360.7  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
off2020.head()
# Out:
#    Unnamed: 0                       Team  2020 Off Tot Pts  2020 Off Pts/G  \
# 0           5   Arizona CardinalsArizona               410            25.6
# 1          17     Atlanta FalconsAtlanta               396            24.8
# 2          18  Baltimore RavensBaltimore               468            29.2
# 3           1       Buffalo BillsBuffalo               501            31.3
# 4          20  Carolina PanthersCarolina               350            21.9
#
#    2020 Off RushYds  2020 Off RYds/G  2020 Off PassYds  2020 Off PYds/G  \
# 0              2237            139.8              3916            244.8
# 1              1532             95.8              4363            272.7
# 2              3071            191.9              2739            171.2
# 3              1723            107.7              4620            288.8
# 4              1704            106.5              3888            243.0
#
#    2020 Off TotYds  2020 Off Yds/G
# 0             6153           384.6
# ...

# %%
def2020.head()
# Out:
#    Unnamed: 0                       Team  2020 Def Tot/Pts  2020 Def Pts/G  \
# 0          12   Arizona CardinalsArizona               367            22.9
# 1          28     Atlanta FalconsAtlanta               414            25.9
# 2           6  Baltimore RavensBaltimore               303            18.9
# 3          13       Buffalo BillsBuffalo               375            23.4
# 4          17  Carolina PanthersCarolina               402            25.1
#
#    2020 Def RushYds  2020 Def RYds/G  2020 Def PassYds  2020 Def PYds/G  \
# 0              2008            125.5              3623            226.4
# 1              1677            104.8              4697            293.6
# 2              1740            108.8              3536            221.0
# 3              1914            119.6              3726            232.9
# 4              1936            121.0              3825            239.1
#
#    2020 Def TotYds  2020 Def Yds/G
# 0             5631           351.9
# ...

# %%
wl2020.head()
# Out:
#    Unnamed: 0               Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0          16  Arizona Cardinals     8       8    0        No     No  2020
# 1           2    Atlanta Falcons     4      12    0        No     No  2020
# 2          21   Baltimore Ravens    11       5    0        No     No  2020
# 3          29      Buffalo Bills    13       3    0        No     No  2020
# 4           6  Carolina Panthers     5      11    0        No     No  2020

# %% [markdown]
# ### Drop unnamed column in all datasets

# %%
nfl2012_2019 = nfl2012_2019.iloc[:, 1:]
off2020 = off2020.iloc[:, 1:]
def2020 = def2020.iloc[:, 1:]
wl2020 = wl2020.iloc[:, 1:]

# %%
nfl2012_2019.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
off2020.head()
# Out:
#                         Team  2020 Off Tot Pts  2020 Off Pts/G  \
# 0   Arizona CardinalsArizona               410            25.6
# 1     Atlanta FalconsAtlanta               396            24.8
# 2  Baltimore RavensBaltimore               468            29.2
# 3       Buffalo BillsBuffalo               501            31.3
# 4  Carolina PanthersCarolina               350            21.9
#
#    2020 Off RushYds  2020 Off RYds/G  2020 Off PassYds  2020 Off PYds/G  \
# 0              2237            139.8              3916            244.8
# 1              1532             95.8              4363            272.7
# 2              3071            191.9              2739            171.2
# 3              1723            107.7              4620            288.8
# 4              1704            106.5              3888            243.0
#
#    2020 Off TotYds  2020 Off Yds/G
# 0             6153           384.6
# 1             5895           368.4
# 2             5810           363.1
# ...

# %%
def2020.head()
# Out:
#                         Team  2020 Def Tot/Pts  2020 Def Pts/G  \
# 0   Arizona CardinalsArizona               367            22.9
# 1     Atlanta FalconsAtlanta               414            25.9
# 2  Baltimore RavensBaltimore               303            18.9
# 3       Buffalo BillsBuffalo               375            23.4
# 4  Carolina PanthersCarolina               402            25.1
#
#    2020 Def RushYds  2020 Def RYds/G  2020 Def PassYds  2020 Def PYds/G  \
# 0              2008            125.5              3623            226.4
# 1              1677            104.8              4697            293.6
# 2              1740            108.8              3536            221.0
# 3              1914            119.6              3726            232.9
# 4              1936            121.0              3825            239.1
#
#    2020 Def TotYds  2020 Def Yds/G
# 0             5631           351.9
# 1             6374           398.4
# 2             5276           329.8
# ...

# %%
wl2020.head()
# Out:
#                 Team  Wins  Losses  Tie Superbowl SB Win  Year
# 0  Arizona Cardinals     8       8    0        No     No  2020
# 1    Atlanta Falcons     4      12    0        No     No  2020
# 2   Baltimore Ravens    11       5    0        No     No  2020
# 3      Buffalo Bills    13       3    0        No     No  2020
# 4  Carolina Panthers     5      11    0        No     No  2020

# %% [markdown]
# ### Rename columns in off/def dataset

# %%
offense2020 = off2020.rename(columns ={"2020 Off Tot Pts": "Off Tot/Pts", "2020 Off Pts/G": "Off Pts/G",
                                                     "2020 Off RushYds": "Off RushYds", "2020 Off RYds/G": "Off RYds/G",
                                                     "2020 Off PassYds": "Off PassYds", "2020 Off PYds/G": "Off PYds/G",
                                                     "2020 Off TotYds": "Off TotYds", "2020 Off Yds/G": "Off Yds/G"})
defense2020 = def2020.rename(columns ={"2020 Def Tot/Pts": "Def Tot/Pts", "2020 Def Pts/G": "Def Pts/G",
                                                     "2020 Def RushYds": "Def RushYds", "2020 Def RYds/G": "Def RYds/G",
                                                     "2020 Def PassYds": "Def PassYds", "2020 Def PYds/G": "Def PYds/G",
                                                     "2020 Def TotYds": "Def TotYds", "2020 Def Yds/G": "Def Yds/G"})

# %%
offense2020.head()
# Out:
#                         Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0   Arizona CardinalsArizona          410       25.6         2237       139.8
# 1     Atlanta FalconsAtlanta          396       24.8         1532        95.8
# 2  Baltimore RavensBaltimore          468       29.2         3071       191.9
# 3       Buffalo BillsBuffalo          501       31.3         1723       107.7
# 4  Carolina PanthersCarolina          350       21.9         1704       106.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G
# 0         3916       244.8        6153      384.6
# 1         4363       272.7        5895      368.4
# 2         2739       171.2        5810      363.1
# 3         4620       288.8        6343      396.4
# 4         3888       243.0        5592      349.5

# %%
defense2020.head()
# Out:
#                         Team  Def Tot/Pts  Def Pts/G  Def RushYds  Def RYds/G  \
# 0   Arizona CardinalsArizona          367       22.9         2008       125.5
# 1     Atlanta FalconsAtlanta          414       25.9         1677       104.8
# 2  Baltimore RavensBaltimore          303       18.9         1740       108.8
# 3       Buffalo BillsBuffalo          375       23.4         1914       119.6
# 4  Carolina PanthersCarolina          402       25.1         1936       121.0
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G
# 0         3623       226.4        5631      351.9
# 1         4697       293.6        6374      398.4
# 2         3536       221.0        5276      329.8
# 3         3726       232.9        5640      352.5
# 4         3825       239.1        5761      360.1

# %% [markdown]
# ### Merge Offense and Defense Data

# %%
off_def2020 = pd.merge(offense2020, defense2020, on='Team')

# %%
off_def2020.head(32)
# Out:
#                                   Team  Off Tot/Pts  Off Pts/G  Off RushYds  \
# 0             Arizona CardinalsArizona          410       25.6         2237
# 1               Atlanta FalconsAtlanta          396       24.8         1532
# 2            Baltimore RavensBaltimore          468       29.2         3071
# 3                 Buffalo BillsBuffalo          501       31.3         1723
# 4            Carolina PanthersCarolina          350       21.9         1704
# 5                 Chicago BearsChicago          372       23.2         1647
# 6         Cincinnati BengalsCincinnati          311       19.4         1668
# 7            Cleveland BrownsCleveland          408       25.5         2374
# 8                 Dallas CowboysDallas          395       24.7         1788
# 9                 Denver BroncosDenver          323       20.2         1918
# 10                Detroit LionsDetroit          377       23.6         1499
# ...

# %% [markdown]
# ### Rename Teams to match merge data

# %%
teamnames20 = {'Arizona CardinalsArizona': 'Arizona Cardinals', 'Atlanta FalconsAtlanta': 'Atlanta Falcons', 
             'Baltimore RavensBaltimore': 'Baltimore Ravens', 'Buffalo BillsBuffalo': 'Buffalo Bills',
            'Carolina PanthersCarolina': 'Carolina Panthers', 'Chicago BearsChicago': 'Chicago Bears',
            'Cincinnati BengalsCincinnati': 'Cincinnati Bengals', 'Cleveland BrownsCleveland': 'Cleveland Browns',
            'Dallas CowboysDallas': 'Dallas Cowboys', 'Denver BroncosDenver': 'Denver Broncos', 
             'Detroit LionsDetroit': 'Detroit Lions', 'Green Bay PackersGreen Bay': 'Green Bay Packers',
            'Houston TexansHouston': 'Houston Texans', 'Indianapolis ColtsIndianapolis': 'Indianapolis Colts',
            'Jacksonville JaguarsJacksonville': 'Jacksonville Jaguars', 'Kansas City ChiefsKansas City': 'Kansas City Chiefs',
            'Los Angeles ChargersLA Chargers': 'Los Angeles Chargers', 'Los Angeles RamsLA Rams': 'Los Angeles Rams',
            'Miami DolphinsMiami': 'Miami Dolphins', 'Minnesota VikingsMinnesota': 'Minnesota Vikings', 
            'New England PatriotsNew England': 'New England Patriots', 'New Orleans SaintsNew Orleans': 'New Orleans Saints',
            'New York GiantsNY Giants': 'New York Giants', 'New York JetsNY Jets': 'New York Jets', 
            'Las Vegas RaidersLas Vegas': 'Las Vegas Raiders', 'Philadelphia EaglesPhiladelphia': 'Philadelphia Eagles',
            'Pittsburgh SteelersPittsburgh': 'Pittsburgh Steelers',
            'San Francisco 49ersSan Francisco': 'San Francisco 49ers', 'Seattle SeahawksSeattle': 'Seattle Seahawks', 
            'Tampa Bay BuccaneersTampa Bay': 'Tampa Bay Buccaneers', 'Tennessee TitansTennessee': 'Tennessee Titans',
            'Washington Football TeamWashington': 'Washington Commanders'}
off_def2020['Team'] = off_def2020['Team'].replace(teamnames20)

# %%
off_def2020.tail(16)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 16      Las Vegas Raiders          434       27.1         1916       119.8
# 17   Los Angeles Chargers          384       24.0         1784       111.5
# 18       Los Angeles Rams          372       23.2         2018       126.1
# 19         Miami Dolphins          404       25.2         1688       105.5
# 20      Minnesota Vikings          430       26.9         2283       142.7
# 21   New England Patriots          326       20.4         2346       146.6
# 22     New Orleans Saints          482       30.1         2265       141.6
# 23        New York Giants          280       17.5         1768       110.5
# 24          New York Jets          243       15.2         1683       105.2
# 25    Philadelphia Eagles          334       20.9         2027       126.7
# 26    Pittsburgh Steelers          416       26.0         1351        84.4
# ...

# %% [markdown]
# ### Put Dataset in Team Ascending Order

# %%
off_def2020 = off_def2020.sort_values("Team")

# %%
off_def2020.tail(16)
# Out:
#                      Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 16      Las Vegas Raiders          434       27.1         1916       119.8
# 17   Los Angeles Chargers          384       24.0         1784       111.5
# 18       Los Angeles Rams          372       23.2         2018       126.1
# 19         Miami Dolphins          404       25.2         1688       105.5
# 20      Minnesota Vikings          430       26.9         2283       142.7
# 21   New England Patriots          326       20.4         2346       146.6
# 22     New Orleans Saints          482       30.1         2265       141.6
# 23        New York Giants          280       17.5         1768       110.5
# 24          New York Jets          243       15.2         1683       105.2
# 25    Philadelphia Eagles          334       20.9         2027       126.7
# 26    Pittsburgh Steelers          416       26.0         1351        84.4
# ...

# %% [markdown]
# ### Merge with Win/Loss Data

# %%
nfl2020 = pd.merge(off_def2020, wl2020, on="Team")

# %%
nfl2020.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          410       25.6         2237       139.8
# 1    Atlanta Falcons          396       24.8         1532        95.8
# 2   Baltimore Ravens          468       29.2         3071       191.9
# 3      Buffalo Bills          501       31.3         1723       107.7
# 4  Carolina Panthers          350       21.9         1704       106.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3916       244.8        6153      384.6          367  ...
# 1         4363       272.7        5895      368.4          414  ...
# 2         2739       171.2        5810      363.1          303  ...
# 3         4620       288.8        6343      396.4          375  ...
# 4         3888       243.0        5592      349.5          402  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2020.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2020complete.csv')

# %% [markdown]
# ### Merge 2012-2020 Data

# %%
nfl2012_2020 = pd.concat([nfl2012_2019, nfl2020], axis=0, join='outer', ignore_index='True')

# %%
nfl2012_2020.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %%
nfl2012_2020.tail()
# Out:
#                       Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 282    San Francisco 49ers          376       23.5         1889       118.1
# 283       Seattle Seahawks          459       28.7         1971       123.2
# 284   Tampa Bay Buccaneers          492       30.8         1519        94.9
# 285       Tennessee Titans          491       30.7         2690       168.1
# 286  Washington Commanders          335       20.9         1611       100.7
#
#      Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 282         4033       252.1        5922      370.1          390  ...
# 283         3941       246.3        5912      369.5          371  ...
# 284         4626       289.1        6145      384.1          355  ...
# 285         3653       228.3        6343      396.4          439  ...
# 286         3465       216.6        5076      317.2          329  ...
#
#      Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# ...

# %% [markdown]
# ### Save Dataset to Mac for future use

# %%
nfl2012_2020.to_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2020merge.csv')

# %% [markdown]
# # Descriptive Statistics for Offense Passing Yards per Game for Each Team

# %% [markdown]
# #### Import Packages

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy import stats

# %% [markdown]
# #### Import NFL Dataset 2012-2022

# %%
nflPass = pd.read_csv('/Users/admin/Desktop/Final_Project/NFL_merged/nfl2012_2022merge.csv')
nflPass.head()
# Out:
#                 Team  Off Tot/Pts  Off Pts/G  Off RushYds  Off RYds/G  \
# 0  Arizona Cardinals          250       15.6         1204        75.2
# 1    Atlanta Falcons          419       26.2         1397        87.3
# 2   Baltimore Ravens          398       24.9         1901       118.8
# 3      Buffalo Bills          344       21.5         2217       138.6
# 4  Carolina Panthers          357       22.3         2088       130.5
#
#    Off PassYds  Off PYds/G  Off TotYds  Off Yds/G  Def Tot/Pts  ...  \
# 0         3005       187.8        4209      263.1          357  ...
# 1         4509       281.8        5906      369.1          299  ...
# 2         3739       233.7        5640      352.5          344  ...
# 3         3269       204.3        5486      342.9          435  ...
# 4         3683       230.2        5771      360.7          363  ...
#
#    Def PassYds  Def PYds/G  Def TotYds  Def Yds/G  Year  Wins  Losses  Tie  \
# 0         3213       200.8        5405      337.8  2012     5      11  0.0
# 1         3878       242.4        5849      365.6  2012    13       3  0.0
# 2         3650       228.1        5615      350.9  2012    10       6  0.0
# 3         3473       217.1        5806      362.9  2012     6      10  0.0
# 4         3568       223.0        5329      333.1  2012     7       9  0.0
#
#    Superbowl  SB Win
# 0         No      No
# 1         No      No
# 2        Yes     Yes
# 3         No      No
# 4         No      No
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Calculating Descriptive Statistics by Team
# #### First filter the data by a single team - I will use the Seattle Seahawks, my favorite team, to start.

# %%
team_name = 'Seattle Seahawks'
seahawks_data = nflPass[nflPass['Team'] == team_name]

# %%
#### Display Offense Passing yards/game by year for the Seahawks

for year in seahawks_data['Year'].unique():
    passydsgame = seahawks_data.loc[seahawks_data['Year'] == year, 'Off PYds/G'].values[0]
    print("Year:", year, "\tPassing Yards/Game:", passydsgame)
# Out:
# Year: 2012 	Passing Yards/Game: 189.4
# Year: 2013 	Passing Yards/Game: 202.2
# Year: 2014 	Passing Yards/Game: 203.1
# Year: 2015 	Passing Yards/Game: 236.9
# Year: 2016 	Passing Yards/Game: 257.8
# Year: 2017 	Passing Yards/Game: 228.6
# Year: 2018 	Passing Yards/Game: 228.6
# Year: 2019 	Passing Yards/Game: 236.9
# Year: 2020 	Passing Yards/Game: 246.3
# Year: 2021 	Passing Yards/Game: 201.9
# Year: 2022 	Passing Yards/Game: 231.4

# %% [markdown]
# #### What is the mean Passing Yards per Game for the Seahawks over all years?

# %%
total_pass_yards_game = seahawks_data['Off PYds/G'].mean()
print(total_pass_yards_game)
# Out:
# 223.9181818181818

# %% [markdown]
# #### Let's calculate several descriptive statistics on Offense Passing Yards per Game for the Seahawks

# %%
mean_value = seahawks_data['Off PYds/G'].mean()
median_value = seahawks_data['Off PYds/G'].median()
std_value = seahawks_data['Off PYds/G'].std()
var_value = seahawks_data['Off PYds/G'].var()
min_value = seahawks_data['Off PYds/G'].min()
max_value = seahawks_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = seahawks_data['Off PYds/G'].sum()
print("Seattle Seahawks Offense Passing Yards/Game Mean:", mean_value)
print("Seattle Seahawks Offense Passing Yards/Game Median:", median_value)
print("Seattle Seahawks Offense Passing Yards/Game Standard Deviation:", std_value)
print("Seattle Seahawks Offense Passing Yards/Game Variance:", var_value)
print("Seattle Seahawks Offense Passing Yards/Game Minimum:", min_value)
print("Seattle Seahawks Offense Passing Yards/Game Maximum:", max_value)
print("Seattle Seahawks Offense Passing Yards/Game Range:", data_range)
print("Seattle Seahawks Total Passing Yards/Game 2012-2022:", total_points)
# Out:
# Seattle Seahawks Offense Passing Yards/Game Mean: 223.9181818181818
# Seattle Seahawks Offense Passing Yards/Game Median: 228.6
# Seattle Seahawks Offense Passing Yards/Game Standard Deviation: 21.603648681730515
# Seattle Seahawks Offense Passing Yards/Game Variance: 466.7176363636366
# Seattle Seahawks Offense Passing Yards/Game Minimum: 189.4
# Seattle Seahawks Offense Passing Yards/Game Maximum: 257.8
# Seattle Seahawks Offense Passing Yards/Game Range: 68.4
# Seattle Seahawks Total Passing Yards/Game 2012-2022: 2463.1

# %% [markdown]
# #### Calculating all Teams Offense Passing Yards per game per year

# %%
team_names = nflPass['Team'].unique()

# Iterate over each team
for team_name in team_names:
    team_data = nflPass[nflPass['Team'] == team_name]
    
    # Display the total offense passing yards per game for each year
    for year in team_data['Year'].unique():
        team_off_rush_ydsgame = team_data.loc[team_data['Year'] == year, 'Off PYds/G'].values[0]
        print("Team:", team_name, "\tYear:", year, "\tPassing Yards/Game:", team_off_rush_ydsgame)
# Out:
# Team: Arizona Cardinals 	Year: 2012 	Passing Yards/Game: 187.8
# Team: Arizona Cardinals 	Year: 2013 	Passing Yards/Game: 250.1
# Team: Arizona Cardinals 	Year: 2014 	Passing Yards/Game: 238.0
# Team: Arizona Cardinals 	Year: 2015 	Passing Yards/Game: 288.5
# Team: Arizona Cardinals 	Year: 2016 	Passing Yards/Game: 258.5
# Team: Arizona Cardinals 	Year: 2017 	Passing Yards/Game: 227.5
# Team: Arizona Cardinals 	Year: 2018 	Passing Yards/Game: 227.5
# Team: Arizona Cardinals 	Year: 2019 	Passing Yards/Game: 217.3
# Team: Arizona Cardinals 	Year: 2020 	Passing Yards/Game: 244.8
# Team: Arizona Cardinals 	Year: 2021 	Passing Yards/Game: 251.5
# Team: Arizona Cardinals 	Year: 2022 	Passing Yards/Game: 213.3
# Team: Atlanta Falcons 	Year: 2012 	Passing Yards/Game: 281.8
# Team: Atlanta Falcons 	Year: 2013 	Passing Yards/Game: 265.2
# Team: Atlanta Falcons 	Year: 2014 	Passing Yards/Game: 284.6
# Team: Atlanta Falcons 	Year: 2015 	Passing Yards/Game: 273.7
# Team: Atlanta Falcons 	Year: 2016 	Passing Yards/Game: 295.3
# Team: Atlanta Falcons 	Year: 2017 	Passing Yards/Game: 249.4
# Team: Atlanta Falcons 	Year: 2018 	Passing Yards/Game: 249.4
# Team: Atlanta Falcons 	Year: 2019 	Passing Yards/Game: 294.6
# Team: Atlanta Falcons 	Year: 2020 	Passing Yards/Game: 272.7
# Team: Atlanta Falcons 	Year: 2021 	Passing Yards/Game: 218.4
# Team: Atlanta Falcons 	Year: 2022 	Passing Yards/Game: 158.8
# Team: Baltimore Ravens 	Year: 2012 	Passing Yards/Game: 233.7
# Team: Baltimore Ravens 	Year: 2013 	Passing Yards/Game: 224.4
# Team: Baltimore Ravens 	Year: 2014 	Passing Yards/Game: 238.7
# Team: Baltimore Ravens 	Year: 2015 	Passing Yards/Game: 266.9
# Team: Baltimore Ravens 	Year: 2016 	Passing Yards/Game: 256.2
# Team: Baltimore Ravens 	Year: 2017 	Passing Yards/Game: 189.4
# Team: Baltimore Ravens 	Year: 2018 	Passing Yards/Game: 189.4
# Team: Baltimore Ravens 	Year: 2019 	Passing Yards/Game: 201.6
# Team: Baltimore Ravens 	Year: 2020 	Passing Yards/Game: 171.2
# Team: Baltimore Ravens 	Year: 2021 	Passing Yards/Game: 233.0
# Team: Baltimore Ravens 	Year: 2022 	Passing Yards/Game: 178.8
# Team: Buffalo Bills 	Year: 2012 	Passing Yards/Game: 204.3
# Team: Buffalo Bills 	Year: 2013 	Passing Yards/Game: 193.9
# Team: Buffalo Bills 	Year: 2014 	Passing Yards/Game: 225.9
# Team: Buffalo Bills 	Year: 2015 	Passing Yards/Game: 208.9
# Team: Buffalo Bills 	Year: 2016 	Passing Yards/Game: 189.8
# Team: Buffalo Bills 	Year: 2017 	Passing Yards/Game: 176.6
# Team: Buffalo Bills 	Year: 2018 	Passing Yards/Game: 176.6
# Team: Buffalo Bills 	Year: 2019 	Passing Yards/Game: 201.8
# Team: Buffalo Bills 	Year: 2020 	Passing Yards/Game: 288.8
# Team: Buffalo Bills 	Year: 2021 	Passing Yards/Game: 252.0
# Team: Buffalo Bills 	Year: 2022 	Passing Yards/Game: 258.1
# Team: Carolina Panthers 	Year: 2012 	Passing Yards/Game: 230.2
# Team: Carolina Panthers 	Year: 2013 	Passing Yards/Game: 190.2
# Team: Carolina Panthers 	Year: 2014 	Passing Yards/Game: 219.4
# Team: Carolina Panthers 	Year: 2015 	Passing Yards/Game: 224.3
# Team: Carolina Panthers 	Year: 2016 	Passing Yards/Game: 230.3
# Team: Carolina Panthers 	Year: 2017 	Passing Yards/Game: 192.3
# Team: Carolina Panthers 	Year: 2018 	Passing Yards/Game: 192.3
# Team: Carolina Panthers 	Year: 2019 	Passing Yards/Game: 228.1
# Team: Carolina Panthers 	Year: 2020 	Passing Yards/Game: 243.0
# Team: Carolina Panthers 	Year: 2021 	Passing Yards/Game: 190.5
# Team: Carolina Panthers 	Year: 2022 	Passing Yards/Game: 176.2
# Team: Chicago Bears 	Year: 2012 	Passing Yards/Game: 187.4
# Team: Chicago Bears 	Year: 2013 	Passing Yards/Game: 267.6
# Team: Chicago Bears 	Year: 2014 	Passing Yards/Game: 237.0
# Team: Chicago Bears 	Year: 2015 	Passing Yards/Game: 228.8
# Team: Chicago Bears 	Year: 2016 	Passing Yards/Game: 248.1
# Team: Chicago Bears 	Year: 2017 	Passing Yards/Game: 175.7
# Team: Chicago Bears 	Year: 2018 	Passing Yards/Game: 175.7
# Team: Chicago Bears 	Year: 2019 	Passing Yards/Game: 205.7
# Team: Chicago Bears 	Year: 2020 	Passing Yards/Game: 228.4
# Team: Chicago Bears 	Year: 2021 	Passing Yards/Game: 188.6
# Team: Chicago Bears 	Year: 2022 	Passing Yards/Game: 130.5
# Team: Cincinnati Bengals 	Year: 2012 	Passing Yards/Game: 223.6
# Team: Cincinnati Bengals 	Year: 2013 	Passing Yards/Game: 258.5
# Team: Cincinnati Bengals 	Year: 2014 	Passing Yards/Game: 213.8
# Team: Cincinnati Bengals 	Year: 2015 	Passing Yards/Game: 245.2
# Team: Cincinnati Bengals 	Year: 2016 	Passing Yards/Game: 246.4
# Team: Cincinnati Bengals 	Year: 2017 	Passing Yards/Game: 195.1
# Team: Cincinnati Bengals 	Year: 2018 	Passing Yards/Game: 195.1
# Team: Cincinnati Bengals 	Year: 2019 	Passing Yards/Game: 228.2
# Team: Cincinnati Bengals 	Year: 2020 	Passing Yards/Game: 215.5
# Team: Cincinnati Bengals 	Year: 2021 	Passing Yards/Game: 259.0
# Team: Cincinnati Bengals 	Year: 2022 	Passing Yards/Game: 265.0
# Team: Cleveland Browns 	Year: 2012 	Passing Yards/Game: 214.7
# Team: Cleveland Browns 	Year: 2013 	Passing Yards/Game: 252.9
# Team: Cleveland Browns 	Year: 2014 	Passing Yards/Game: 216.6
# Team: Cleveland Browns 	Year: 2015 	Passing Yards/Game: 236.4
# Team: Cleveland Browns 	Year: 2016 	Passing Yards/Game: 204.0
# Team: Cleveland Browns 	Year: 2017 	Passing Yards/Game: 201.8
# Team: Cleveland Browns 	Year: 2018 	Passing Yards/Game: 201.8
# Team: Cleveland Browns 	Year: 2019 	Passing Yards/Game: 222.1
# Team: Cleveland Browns 	Year: 2020 	Passing Yards/Game: 221.2
# Team: Cleveland Browns 	Year: 2021 	Passing Yards/Game: 195.3
# Team: Cleveland Browns 	Year: 2022 	Passing Yards/Game: 202.6
# Team: Dallas Cowboys 	Year: 2012 	Passing Yards/Game: 295.6
# Team: Dallas Cowboys 	Year: 2013 	Passing Yards/Game: 247.1
# Team: Dallas Cowboys 	Year: 2014 	Passing Yards/Game: 236.5
# Team: Dallas Cowboys 	Year: 2015 	Passing Yards/Game: 216.9
# Team: Dallas Cowboys 	Year: 2016 	Passing Yards/Game: 226.9
# Team: Dallas Cowboys 	Year: 2017 	Passing Yards/Game: 196.3
# Team: Dallas Cowboys 	Year: 2018 	Passing Yards/Game: 196.3
# Team: Dallas Cowboys 	Year: 2019 	Passing Yards/Game: 296.9
# Team: Dallas Cowboys 	Year: 2020 	Passing Yards/Game: 260.1
# Team: Dallas Cowboys 	Year: 2021 	Passing Yards/Game: 282.4
# Team: Dallas Cowboys 	Year: 2022 	Passing Yards/Game: 219.8
# Team: Denver Broncos 	Year: 2012 	Passing Yards/Game: 283.4
# Team: Denver Broncos 	Year: 2013 	Passing Yards/Game: 340.2
# Team: Denver Broncos 	Year: 2014 	Passing Yards/Game: 291.3
# Team: Denver Broncos 	Year: 2015 	Passing Yards/Game: 248.1
# Team: Denver Broncos 	Year: 2016 	Passing Yards/Game: 230.3
# Team: Denver Broncos 	Year: 2017 	Passing Yards/Game: 208.3
# Team: Denver Broncos 	Year: 2018 	Passing Yards/Game: 208.3
# Team: Denver Broncos 	Year: 2019 	Passing Yards/Game: 194.7
# Team: Denver Broncos 	Year: 2020 	Passing Yards/Game: 215.7
# Team: Denver Broncos 	Year: 2021 	Passing Yards/Game: 211.4
# Team: Denver Broncos 	Year: 2022 	Passing Yards/Game: 211.3
# Team: Detroit Lions 	Year: 2012 	Passing Yards/Game: 307.9
# Team: Detroit Lions 	Year: 2013 	Passing Yards/Game: 280.1
# Team: Detroit Lions 	Year: 2014 	Passing Yards/Game: 251.9
# Team: Detroit Lions 	Year: 2015 	Passing Yards/Game: 263.2
# Team: Detroit Lions 	Year: 2016 	Passing Yards/Game: 256.9
# Team: Detroit Lions 	Year: 2017 	Passing Yards/Game: 261.4
# Team: Detroit Lions 	Year: 2018 	Passing Yards/Game: 261.4
# Team: Detroit Lions 	Year: 2019 	Passing Yards/Game: 243.8
# Team: Detroit Lions 	Year: 2020 	Passing Yards/Game: 256.5
# Team: Detroit Lions 	Year: 2021 	Passing Yards/Game: 211.6
# Team: Detroit Lions 	Year: 2022 	Passing Yards/Game: 251.8
# Team: Green Bay Packers 	Year: 2012 	Passing Yards/Game: 253.1
# Team: Green Bay Packers 	Year: 2013 	Passing Yards/Game: 266.8
# Team: Green Bay Packers 	Year: 2014 	Passing Yards/Game: 266.3
# Team: Green Bay Packers 	Year: 2015 	Passing Yards/Game: 218.9
# Team: Green Bay Packers 	Year: 2016 	Passing Yards/Game: 262.4
# Team: Green Bay Packers 	Year: 2017 	Passing Yards/Game: 197.9
# Team: Green Bay Packers 	Year: 2018 	Passing Yards/Game: 197.9
# Team: Green Bay Packers 	Year: 2019 	Passing Yards/Game: 233.3
# Team: Green Bay Packers 	Year: 2020 	Passing Yards/Game: 256.6
# Team: Green Bay Packers 	Year: 2021 	Passing Yards/Game: 253.8
# Team: Green Bay Packers 	Year: 2022 	Passing Yards/Game: 213.6
# Team: Houston Texans 	Year: 2012 	Passing Yards/Game: 239.4
# Team: Houston Texans 	Year: 2013 	Passing Yards/Game: 238.3
# Team: Houston Texans 	Year: 2014 	Passing Yards/Game: 209.5
# Team: Houston Texans 	Year: 2015 	Passing Yards/Game: 239.6
# Team: Houston Texans 	Year: 2016 	Passing Yards/Game: 198.5
# Team: Houston Texans 	Year: 2017 	Passing Yards/Game: 204.9
# Team: Houston Texans 	Year: 2018 	Passing Yards/Game: 204.9
# Team: Houston Texans 	Year: 2019 	Passing Yards/Game: 236.4
# Team: Houston Texans 	Year: 2020 	Passing Yards/Game: 283.6
# Team: Houston Texans 	Year: 2021 	Passing Yards/Game: 194.4
# Team: Houston Texans 	Year: 2022 	Passing Yards/Game: 196.7
# Team: Indianapolis Colts 	Year: 2012 	Passing Yards/Game: 258.0
# Team: Indianapolis Colts 	Year: 2013 	Passing Yards/Game: 232.8
# Team: Indianapolis Colts 	Year: 2014 	Passing Yards/Game: 305.9
# Team: Indianapolis Colts 	Year: 2015 	Passing Yards/Game: 231.5
# Team: Indianapolis Colts 	Year: 2016 	Passing Yards/Game: 262.6
# Team: Indianapolis Colts 	Year: 2017 	Passing Yards/Game: 180.8
# Team: Indianapolis Colts 	Year: 2018 	Passing Yards/Game: 180.8
# Team: Indianapolis Colts 	Year: 2019 	Passing Yards/Game: 194.2
# Team: Indianapolis Colts 	Year: 2020 	Passing Yards/Game: 253.3
# Team: Indianapolis Colts 	Year: 2021 	Passing Yards/Game: 197.7
# Team: Indianapolis Colts 	Year: 2022 	Passing Yards/Game: 201.9
# Team: Jacksonville Jaguars 	Year: 2012 	Passing Yards/Game: 213.7
# Team: Jacksonville Jaguars 	Year: 2013 	Passing Yards/Game: 215.1
# Team: Jacksonville Jaguars 	Year: 2014 	Passing Yards/Game: 187.6
# Team: Jacksonville Jaguars 	Year: 2015 	Passing Yards/Game: 256.8
# Team: Jacksonville Jaguars 	Year: 2016 	Passing Yards/Game: 233.0
# Team: Jacksonville Jaguars 	Year: 2017 	Passing Yards/Game: 224.6
# Team: Jacksonville Jaguars 	Year: 2018 	Passing Yards/Game: 224.6
# Team: Jacksonville Jaguars 	Year: 2019 	Passing Yards/Game: 235.0
# Team: Jacksonville Jaguars 	Year: 2020 	Passing Yards/Game: 231.2
# Team: Jacksonville Jaguars 	Year: 2021 	Passing Yards/Game: 202.1
# Team: Jacksonville Jaguars 	Year: 2022 	Passing Yards/Game: 232.9
# Team: Kansas City Chiefs 	Year: 2012 	Passing Yards/Game: 169.6
# Team: Kansas City Chiefs 	Year: 2013 	Passing Yards/Game: 208.8
# Team: Kansas City Chiefs 	Year: 2014 	Passing Yards/Game: 198.9
# Team: Kansas City Chiefs 	Year: 2015 	Passing Yards/Game: 203.4
# Team: Kansas City Chiefs 	Year: 2016 	Passing Yards/Game: 233.8
# Team: Kansas City Chiefs 	Year: 2017 	Passing Yards/Game: 256.5
# Team: Kansas City Chiefs 	Year: 2018 	Passing Yards/Game: 256.5
# Team: Kansas City Chiefs 	Year: 2019 	Passing Yards/Game: 281.1
# Team: Kansas City Chiefs 	Year: 2020 	Passing Yards/Game: 303.4
# Team: Kansas City Chiefs 	Year: 2021 	Passing Yards/Game: 281.8
# Team: Kansas City Chiefs 	Year: 2022 	Passing Yards/Game: 297.8
# Team: Las Vegas Raiders 	Year: 2012 	Passing Yards/Game: 255.2
# Team: Las Vegas Raiders 	Year: 2013 	Passing Yards/Game: 208.8
# Team: Las Vegas Raiders 	Year: 2014 	Passing Yards/Game: 204.7
# Team: Las Vegas Raiders 	Year: 2015 	Passing Yards/Game: 242.4
# Team: Las Vegas Raiders 	Year: 2016 	Passing Yards/Game: 253.2
# Team: Las Vegas Raiders 	Year: 2017 	Passing Yards/Game: 226.9
# Team: Las Vegas Raiders 	Year: 2018 	Passing Yards/Game: 226.9
# Team: Las Vegas Raiders 	Year: 2019 	Passing Yards/Game: 245.4
# Team: Las Vegas Raiders 	Year: 2020 	Passing Yards/Game: 263.6
# Team: Las Vegas Raiders 	Year: 2021 	Passing Yards/Game: 268.6
# Team: Las Vegas Raiders 	Year: 2022 	Passing Yards/Game: 231.4
# Team: Los Angeles Chargers 	Year: 2012 	Passing Yards/Game: 205.9
# Team: Los Angeles Chargers 	Year: 2013 	Passing Yards/Game: 270.5
# Team: Los Angeles Chargers 	Year: 2014 	Passing Yards/Game: 256.1
# Team: Los Angeles Chargers 	Year: 2015 	Passing Yards/Game: 286.9
# Team: Los Angeles Chargers 	Year: 2016 	Passing Yards/Game: 262.4
# Team: Los Angeles Chargers 	Year: 2017 	Passing Yards/Game: 276.9
# Team: Los Angeles Chargers 	Year: 2018 	Passing Yards/Game: 276.9
# Team: Los Angeles Chargers 	Year: 2019 	Passing Yards/Game: 276.6
# Team: Los Angeles Chargers 	Year: 2020 	Passing Yards/Game: 270.6
# Team: Los Angeles Chargers 	Year: 2021 	Passing Yards/Game: 282.4
# Team: Los Angeles Chargers 	Year: 2022 	Passing Yards/Game: 269.6
# Team: Los Angeles Rams 	Year: 2012 	Passing Yards/Game: 221.9
# Team: Los Angeles Rams 	Year: 2013 	Passing Yards/Game: 195.3
# Team: Los Angeles Rams 	Year: 2014 	Passing Yards/Game: 212.5
# Team: Los Angeles Rams 	Year: 2015 	Passing Yards/Game: 175.3
# Team: Los Angeles Rams 	Year: 2016 	Passing Yards/Game: 184.4
# Team: Los Angeles Rams 	Year: 2017 	Passing Yards/Game: 239.4
# Team: Los Angeles Rams 	Year: 2018 	Passing Yards/Game: 239.4
# Team: Los Angeles Rams 	Year: 2019 	Passing Yards/Game: 281.2
# Team: Los Angeles Rams 	Year: 2020 	Passing Yards/Game: 250.9
# Team: Los Angeles Rams 	Year: 2021 	Passing Yards/Game: 273.1
# Team: Los Angeles Rams 	Year: 2022 	Passing Yards/Game: 182.8
# Team: Miami Dolphins 	Year: 2012 	Passing Yards/Game: 198.9
# Team: Miami Dolphins 	Year: 2013 	Passing Yards/Game: 222.9
# Team: Miami Dolphins 	Year: 2014 	Passing Yards/Game: 233.1
# Team: Miami Dolphins 	Year: 2015 	Passing Yards/Game: 238.2
# Team: Miami Dolphins 	Year: 2016 	Passing Yards/Game: 218.8
# Team: Miami Dolphins 	Year: 2017 	Passing Yards/Game: 220.9
# Team: Miami Dolphins 	Year: 2018 	Passing Yards/Game: 220.9
# Team: Miami Dolphins 	Year: 2019 	Passing Yards/Game: 237.8
# Team: Miami Dolphins 	Year: 2020 	Passing Yards/Game: 233.5
# Team: Miami Dolphins 	Year: 2021 	Passing Yards/Game: 214.8
# Team: Miami Dolphins 	Year: 2022 	Passing Yards/Game: 265.4
# Team: Minnesota Vikings 	Year: 2012 	Passing Yards/Game: 171.9
# Team: Minnesota Vikings 	Year: 2013 	Passing Yards/Game: 214.2
# Team: Minnesota Vikings 	Year: 2014 	Passing Yards/Game: 202.8
# Team: Minnesota Vikings 	Year: 2015 	Passing Yards/Game: 183.0
# Team: Minnesota Vikings 	Year: 2016 	Passing Yards/Game: 239.8
# Team: Minnesota Vikings 	Year: 2017 	Passing Yards/Game: 234.6
# Team: Minnesota Vikings 	Year: 2018 	Passing Yards/Game: 234.6
# Team: Minnesota Vikings 	Year: 2019 	Passing Yards/Game: 220.2
# Team: Minnesota Vikings 	Year: 2020 	Passing Yards/Game: 250.6
# Team: Minnesota Vikings 	Year: 2021 	Passing Yards/Game: 249.3
# Team: Minnesota Vikings 	Year: 2022 	Passing Yards/Game: 263.8
# Team: New England Patriots 	Year: 2012 	Passing Yards/Game: 291.4
# Team: New England Patriots 	Year: 2013 	Passing Yards/Game: 255.4
# Team: New England Patriots 	Year: 2014 	Passing Yards/Game: 257.6
# Team: New England Patriots 	Year: 2015 	Passing Yards/Game: 286.7
# Team: New England Patriots 	Year: 2016 	Passing Yards/Game: 269.2
# Team: New England Patriots 	Year: 2017 	Passing Yards/Game: 276.1
# Team: New England Patriots 	Year: 2018 	Passing Yards/Game: 276.1
# Team: New England Patriots 	Year: 2019 	Passing Yards/Game: 247.6
# Team: New England Patriots 	Year: 2020 	Passing Yards/Game: 180.6
# Team: New England Patriots 	Year: 2021 	Passing Yards/Game: 226.9
# Team: New England Patriots 	Year: 2022 	Passing Yards/Game: 208.0
# Team: New Orleans Saints 	Year: 2012 	Passing Yards/Game: 312.3
# Team: New Orleans Saints 	Year: 2013 	Passing Yards/Game: 307.4
# Team: New Orleans Saints 	Year: 2014 	Passing Yards/Game: 297.8
# Team: New Orleans Saints 	Year: 2015 	Passing Yards/Game: 310.6
# Team: New Orleans Saints 	Year: 2016 	Passing Yards/Game: 317.1
# Team: New Orleans Saints 	Year: 2017 	Passing Yards/Game: 261.8
# Team: New Orleans Saints 	Year: 2019 	Passing Yards/Game: 265.2
# Team: New Orleans Saints 	Year: 2020 	Passing Yards/Game: 234.9
# Team: New Orleans Saints 	Year: 2021 	Passing Yards/Game: 187.4
# Team: New Orleans Saints 	Year: 2022 	Passing Yards/Game: 217.2
# Team: New York Giants 	Year: 2012 	Passing Yards/Game: 239.1
# Team: New York Giants 	Year: 2013 	Passing Yards/Game: 224.2
# Team: New York Giants 	Year: 2014 	Passing Yards/Game: 267.0
# Team: New York Giants 	Year: 2015 	Passing Yards/Game: 271.4
# Team: New York Giants 	Year: 2016 	Passing Yards/Game: 242.4
# Team: New York Giants 	Year: 2017 	Passing Yards/Game: 217.4
# Team: New York Giants 	Year: 2018 	Passing Yards/Game: 217.4
# Team: New York Giants 	Year: 2019 	Passing Yards/Game: 233.2
# Team: New York Giants 	Year: 2020 	Passing Yards/Game: 189.1
# Team: New York Giants 	Year: 2021 	Passing Yards/Game: 188.0
# Team: New York Giants 	Year: 2022 	Passing Yards/Game: 185.7
# Team: New York Jets 	Year: 2012 	Passing Yards/Game: 180.7
# Team: New York Jets 	Year: 2013 	Passing Yards/Game: 183.2
# Team: New York Jets 	Year: 2014 	Passing Yards/Game: 184.1
# Team: New York Jets 	Year: 2015 	Passing Yards/Game: 253.6
# Team: New York Jets 	Year: 2016 	Passing Yards/Game: 216.6
# Team: New York Jets 	Year: 2017 	Passing Yards/Game: 198.9
# Team: New York Jets 	Year: 2018 	Passing Yards/Game: 198.9
# Team: New York Jets 	Year: 2019 	Passing Yards/Game: 194.4
# Team: New York Jets 	Year: 2020 	Passing Yards/Game: 174.8
# Team: New York Jets 	Year: 2021 	Passing Yards/Game: 208.3
# Team: New York Jets 	Year: 2022 	Passing Yards/Game: 219.0
# Team: Philadelphia Eagles 	Year: 2012 	Passing Yards/Game: 236.9
# Team: Philadelphia Eagles 	Year: 2013 	Passing Yards/Game: 256.9
# Team: Philadelphia Eagles 	Year: 2014 	Passing Yards/Game: 272.2
# Team: Philadelphia Eagles 	Year: 2015 	Passing Yards/Game: 255.4
# Team: Philadelphia Eagles 	Year: 2016 	Passing Yards/Game: 224.1
# Team: Philadelphia Eagles 	Year: 2017 	Passing Yards/Game: 233.6
# Team: Philadelphia Eagles 	Year: 2018 	Passing Yards/Game: 233.6
# Team: Philadelphia Eagles 	Year: 2019 	Passing Yards/Game: 239.6
# Team: Philadelphia Eagles 	Year: 2020 	Passing Yards/Game: 207.9
# Team: Philadelphia Eagles 	Year: 2021 	Passing Yards/Game: 200.2
# Team: Philadelphia Eagles 	Year: 2022 	Passing Yards/Game: 241.5
# Team: Pittsburgh Steelers 	Year: 2012 	Passing Yards/Game: 236.7
# Team: Pittsburgh Steelers 	Year: 2013 	Passing Yards/Game: 251.1
# Team: Pittsburgh Steelers 	Year: 2014 	Passing Yards/Game: 301.6
# Team: Pittsburgh Steelers 	Year: 2015 	Passing Yards/Game: 287.7
# Team: Pittsburgh Steelers 	Year: 2016 	Passing Yards/Game: 262.6
# Team: Pittsburgh Steelers 	Year: 2017 	Passing Yards/Game: 273.8
# Team: Pittsburgh Steelers 	Year: 2018 	Passing Yards/Game: 273.8
# Team: Pittsburgh Steelers 	Year: 2019 	Passing Yards/Game: 186.3
# Team: Pittsburgh Steelers 	Year: 2020 	Passing Yards/Game: 250.2
# Team: Pittsburgh Steelers 	Year: 2021 	Passing Yards/Game: 222.2
# Team: Pittsburgh Steelers 	Year: 2022 	Passing Yards/Game: 200.6
# Team: San Francisco 49ers 	Year: 2012 	Passing Yards/Game: 206.1
# Team: San Francisco 49ers 	Year: 2013 	Passing Yards/Game: 186.2
# Team: San Francisco 49ers 	Year: 2014 	Passing Yards/Game: 191.4
# Team: San Francisco 49ers 	Year: 2015 	Passing Yards/Game: 207.2
# Team: San Francisco 49ers 	Year: 2016 	Passing Yards/Game: 181.9
# Team: San Francisco 49ers 	Year: 2017 	Passing Yards/Game: 245.3
# Team: San Francisco 49ers 	Year: 2018 	Passing Yards/Game: 245.3
# Team: San Francisco 49ers 	Year: 2019 	Passing Yards/Game: 237.0
# Team: San Francisco 49ers 	Year: 2020 	Passing Yards/Game: 252.1
# Team: San Francisco 49ers 	Year: 2021 	Passing Yards/Game: 248.3
# Team: San Francisco 49ers 	Year: 2022 	Passing Yards/Game: 226.8
# Team: Seattle Seahawks 	Year: 2012 	Passing Yards/Game: 189.4
# Team: Seattle Seahawks 	Year: 2013 	Passing Yards/Game: 202.2
# Team: Seattle Seahawks 	Year: 2014 	Passing Yards/Game: 203.1
# Team: Seattle Seahawks 	Year: 2015 	Passing Yards/Game: 236.9
# Team: Seattle Seahawks 	Year: 2016 	Passing Yards/Game: 257.8
# Team: Seattle Seahawks 	Year: 2017 	Passing Yards/Game: 228.6
# Team: Seattle Seahawks 	Year: 2018 	Passing Yards/Game: 228.6
# Team: Seattle Seahawks 	Year: 2019 	Passing Yards/Game: 236.9
# Team: Seattle Seahawks 	Year: 2020 	Passing Yards/Game: 246.3
# Team: Seattle Seahawks 	Year: 2021 	Passing Yards/Game: 201.9
# Team: Seattle Seahawks 	Year: 2022 	Passing Yards/Game: 231.4
# Team: Tampa Bay Buccaneers 	Year: 2012 	Passing Yards/Game: 248.9
# Team: Tampa Bay Buccaneers 	Year: 2013 	Passing Yards/Game: 176.2
# Team: Tampa Bay Buccaneers 	Year: 2014 	Passing Yards/Game: 206.1
# Team: Tampa Bay Buccaneers 	Year: 2015 	Passing Yards/Game: 240.8
# Team: Tampa Bay Buccaneers 	Year: 2016 	Passing Yards/Game: 245.4
# Team: Tampa Bay Buccaneers 	Year: 2017 	Passing Yards/Game: 272.9
# Team: Tampa Bay Buccaneers 	Year: 2018 	Passing Yards/Game: 272.9
# Team: Tampa Bay Buccaneers 	Year: 2019 	Passing Yards/Game: 302.8
# Team: Tampa Bay Buccaneers 	Year: 2020 	Passing Yards/Game: 289.1
# Team: Tampa Bay Buccaneers 	Year: 2021 	Passing Yards/Game: 307.6
# Team: Tampa Bay Buccaneers 	Year: 2022 	Passing Yards/Game: 269.8
# Team: Tennessee Titans 	Year: 2012 	Passing Yards/Game: 207.7
# Team: Tennessee Titans 	Year: 2013 	Passing Yards/Game: 218.5
# Team: Tennessee Titans 	Year: 2014 	Passing Yards/Game: 213.2
# Team: Tennessee Titans 	Year: 2015 	Passing Yards/Game: 218.9
# Team: Tennessee Titans 	Year: 2016 	Passing Yards/Game: 221.3
# Team: Tennessee Titans 	Year: 2017 	Passing Yards/Game: 199.4
# Team: Tennessee Titans 	Year: 2018 	Passing Yards/Game: 199.4
# Team: Tennessee Titans 	Year: 2019 	Passing Yards/Game: 223.9
# Team: Tennessee Titans 	Year: 2020 	Passing Yards/Game: 228.3
# Team: Tennessee Titans 	Year: 2021 	Passing Yards/Game: 201.1
# Team: Tennessee Titans 	Year: 2022 	Passing Yards/Game: 171.4
# Team: Washington Commanders 	Year: 2012 	Passing Yards/Game: 213.9
# Team: Washington Commanders 	Year: 2013 	Passing Yards/Game: 234.4
# Team: Washington Commanders 	Year: 2014 	Passing Yards/Game: 252.9
# Team: Washington Commanders 	Year: 2015 	Passing Yards/Game: 255.9
# Team: Washington Commanders 	Year: 2016 	Passing Yards/Game: 297.4
# Team: Washington Commanders 	Year: 2017 	Passing Yards/Game: 234.4
# Team: Washington Commanders 	Year: 2018 	Passing Yards/Game: 234.4
# Team: Washington Commanders 	Year: 2019 	Passing Yards/Game: 175.8
# Team: Washington Commanders 	Year: 2020 	Passing Yards/Game: 216.6
# Team: Washington Commanders 	Year: 2021 	Passing Yards/Game: 202.4
# Team: Washington Commanders 	Year: 2022 	Passing Yards/Game: 204.2

# %% [markdown]
# #### Calculate Descriptive Statistics on Passing Yards per game for all Teams. These statistics are the Offense Passing Yards per game and their mean, median, standard deviation, variance, min, max, range, and sum.

# %%
### Arizona Cardinals

team_name1 = 'Arizona Cardinals'
cardinals_data = nflPass[nflPass['Team'] == team_name1]
mean_value = cardinals_data['Off PYds/G'].mean()
median_value = cardinals_data['Off PYds/G'].median()
std_value = cardinals_data['Off PYds/G'].std()
var_value = cardinals_data['Off PYds/G'].var()
min_value = cardinals_data['Off PYds/G'].min()
max_value = cardinals_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = cardinals_data['Off PYds/G'].sum()
print("Arizona Cardinals Offense Passing Yards/Game Mean:", mean_value)
print("Arizona Cardinals Offense Passing Yards/Game Median:", median_value)
print("Arizona Cardinals Offense Passing Yards/Game Standard Deviation:", std_value)
print("Arizona Cardinals Offense Passing Yards/Game Variance:", var_value)
print("Arizona Cardinals Offense Passing Yards/Game Minimum:", min_value)
print("Arizona Cardinals Offense Passing Yards/Game Maximum:", max_value)
print("Arizona Cardinals Offense Passing Yards/Game Range:", data_range)
print("Arizona Cardinals Total Passing Yards/Game 2012-2022:", total_points)

### Atlanta Falcons

team_name2 = 'Atlanta Falcons'
falcons_data = nflPass[nflPass['Team'] == team_name2]
mean_value = falcons_data['Off PYds/G'].mean()
median_value = falcons_data['Off PYds/G'].median()
std_value = falcons_data['Off PYds/G'].std()
var_value = falcons_data['Off PYds/G'].var()
min_value = falcons_data['Off PYds/G'].min()
max_value = falcons_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = falcons_data['Off PYds/G'].sum()
print("Atlanta Falcons Offense Passing Yards/Game Mean:", mean_value)
print("Atlanta Falcons Offense Passing Yards/Game Median:", median_value)
print("Atlanta Falcons Offense Passing Yards/Game Standard Deviation:", std_value)
print("Atlanta Falcons Offense Passing Yards/Game Variance:", var_value)
print("Atlanta Falcons Offense Passing Yards/Game Minimum:", min_value)
print("Atlanta Falcons Offense Passing Yards/Game Maximum:", max_value)
print("Atlanta Falcons Offense Passing Yards/Game Range:", data_range)
print("Atlanta Falcons Total Passing Yards/Game 2012-2022:", total_points)

### Baltimore Ravens

team_name3 = 'Baltimore Ravens'
ravens_data = nflPass[nflPass['Team'] == team_name3]
mean_value = ravens_data['Off PYds/G'].mean()
median_value = ravens_data['Off PYds/G'].median()
std_value = ravens_data['Off PYds/G'].std()
var_value = ravens_data['Off PYds/G'].var()
min_value = ravens_data['Off PYds/G'].min()
max_value = ravens_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = ravens_data['Off PYds/G'].sum()
print("Baltimore Ravens Offense Passing Yards/Game Mean:", mean_value)
print("Baltimore Ravens Offense Passing Yards/Game Median:", median_value)
print("Baltimore Ravens Offense Passing Yards/Game Standard Deviation:", std_value)
print("Baltimore Ravens Offense Passing Yards/Game Variance:", var_value)
print("Baltimore Ravens Offense Passing Yards/Game Minimum:", min_value)
print("Baltimore Ravens Offense Passing Yards/Game Maximum:", max_value)
print("Baltimore Ravens Offense Passing Yards/Game  Range:", data_range)
print("Baltimore Ravens Total Passing Yards/Game 2012-2022:", total_points)

### Buffalo Bills

team_name4 = 'Buffalo Bills'
bills_data = nflPass[nflPass['Team'] == team_name4]
mean_value = bills_data['Off PYds/G'].mean()
median_value = bills_data['Off PYds/G'].median()
std_value = bills_data['Off PYds/G'].std()
var_value = bills_data['Off PYds/G'].var()
min_value = bills_data['Off PYds/G'].min()
max_value = bills_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = bills_data['Off PYds/G'].sum()
print("Buffalo Bills Offense Passing Yards/Game Mean:", mean_value)
print("Buffalo Bills Offense Passing Yards/Game Median:", median_value)
print("Buffalo Bills Offense Passing Yards/Game Standard Deviation:", std_value)
print("Buffalo Bills Offense Passing Yards/Game Variance:", var_value)
print("Buffalo Bills Offense Passing Yards/Game Minimum:", min_value)
print("Buffalo Bills Offense Passing Yards/Game Maximum:", max_value)
print("Buffalo Bills Offense Passing Yards/Game Range:", data_range)
print("Buffalo Bills Total Passing Yards/Game 2012-2022:", total_points)

### Carolina Panthers

team_name5 = 'Carolina Panthers'
panthers_data = nflPass[nflPass['Team'] == team_name5]
mean_value = panthers_data['Off PYds/G'].mean()
median_value = panthers_data['Off PYds/G'].median()
std_value = panthers_data['Off PYds/G'].std()
var_value = panthers_data['Off PYds/G'].var()
min_value = panthers_data['Off PYds/G'].min()
max_value = panthers_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = panthers_data['Off PYds/G'].sum()
print("Carolina Panthers Offense Passing Yards/Game Mean:", mean_value)
print("Carolina Panthers Offense Passing Yards/Game Median:", median_value)
print("Carolina Panthers Offense Passing Yards/Game Standard Deviation:", std_value)
print("Carolina Panthers Offense Passing Yards/Game Variance:", var_value)
print("Carolina Panthers Offense Passing Yards/Game Minimum:", min_value)
print("Carolina Panthers Offense Passing Yards/Game Maximum:", max_value)
print("Carolina Panthers Offense Passing Yards/Game Range:", data_range)
print("Carolina Panthers Total Passing Yards/Game 2012-2022:", total_points)

### Chicago Bears

team_name6 = 'Chicago Bears'
bears_data = nflPass[nflPass['Team'] == team_name6]
mean_value = bears_data['Off PYds/G'].mean()
median_value = bears_data['Off PYds/G'].median()
std_value = bears_data['Off PYds/G'].std()
var_value = bears_data['Off PYds/G'].var()
min_value = bears_data['Off PYds/G'].min()
max_value = bears_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = bears_data['Off PYds/G'].sum()
print("Chicago Bears Offense Passing Yards/Game Mean:", mean_value)
print("Chicago Bears Offense Passing Yards/Game Median:", median_value)
print("Chicago Bears Offense Passing Yards/Game Standard Deviation:", std_value)
print("Chicago Bears Offense Passing Yards/Game Variance:", var_value)
print("Chicago Bears Offense Passing Yards/Game Minimum:", min_value)
print("Chicago Bears Offense Passing Yards/Game Maximum:", max_value)
print("Chicago Bears Offense Passing Yards/Game Range:", data_range)
print("Chicago Bears Total Passing Yards/Game 2012-2022:", total_points)

### Cincinnati Bengals

team_name7 = 'Cincinnati Bengals'
bengals_data = nflPass[nflPass['Team'] == team_name7]
mean_value = bengals_data['Off PYds/G'].mean()
median_value = bengals_data['Off PYds/G'].median()
std_value = bengals_data['Off PYds/G'].std()
var_value = bengals_data['Off PYds/G'].var()
min_value = bengals_data['Off PYds/G'].min()
max_value = bengals_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = bengals_data['Off PYds/G'].sum()
print("Cincinnati Bengals Offense Passing Yards/Game Mean:", mean_value)
print("Cincinnati Bengals Offense Passing Yards/Game Median:", median_value)
print("Cincinnati Bengals Offense Passing Yards/Game Standard Deviation:", std_value)
print("Cincinnati Bengals Offense Passing Yards/Game Variance:", var_value)
print("Cincinnati Bengals Offense Passing Yards/Game Minimum:", min_value)
print("Cincinnati Bengals Offense Passing Yards/Game Maximum:", max_value)
print("Cincinnati Bengals Offense Passing Yards/Game Range:", data_range)
print("Cincinnati Bengals Total Passing Yards/Game 2012-2022:", total_points)

### Cleveland Browns

team_name8 = 'Cleveland Browns'
browns_data = nflPass[nflPass['Team'] == team_name8]
mean_value = browns_data['Off PYds/G'].mean()
median_value = browns_data['Off PYds/G'].median()
std_value = browns_data['Off PYds/G'].std()
var_value = browns_data['Off PYds/G'].var()
min_value = browns_data['Off PYds/G'].min()
max_value = browns_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = browns_data['Off PYds/G'].sum()
print("Cleveland Browns Offense Passing Yards/Game Mean:", mean_value)
print("Cleveland Browns Offense Passing Yards/Game Median:", median_value)
print("Cleveland Browns Offense Passing Yards/Game Standard Deviation:", std_value)
print("Cleveland Browns Offense Passing Yards/Game Variance:", var_value)
print("Cleveland Browns Offense Passing Yards/Game Minimum:", min_value)
print("Cleveland Browns Offense Passing Yards/Game Maximum:", max_value)
print("Cleveland Browns Offense Passing Yards/Game Range:", data_range)
print("Cleveland Browns Total Passing Yards/Game 2012-2022:", total_points)

### Dallas Cowboys

team_name9 = 'Dallas Cowboys'
cowboys_data = nflPass[nflPass['Team'] == team_name9]
mean_value = cowboys_data['Off PYds/G'].mean()
median_value = cowboys_data['Off PYds/G'].median()
std_value = cowboys_data['Off PYds/G'].std()
var_value = cowboys_data['Off PYds/G'].var()
min_value = cowboys_data['Off PYds/G'].min()
max_value = cowboys_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = cowboys_data['Off PYds/G'].sum()
print("Dallas Cowboys Offense Passing Yards/Game Mean:", mean_value)
print("Dallas Cowboys Offense Passing Yards/Game Median:", median_value)
print("Dallas Cowboys Offense Passing Yards/Game Standard Deviation:", std_value)
print("Dallas Cowboys Offense Passing Yards/Game Variance:", var_value)
print("Dallas Cowboys Offense Passing Yards/Game Minimum:", min_value)
print("Dallas Cowboys Offense Passing Yards/Game Maximum:", max_value)
print("Dallas Cowboys Offense Passing Yards/Game Range:", data_range)
print("Dallas Cowboys Total Passing Yards/Game 2012-2022:", total_points)

### Denver Broncos

team_name10 = 'Denver Broncos'
broncos_data = nflPass[nflPass['Team'] == team_name10]
mean_value = broncos_data['Off PYds/G'].mean()
median_value = broncos_data['Off PYds/G'].median()
std_value = broncos_data['Off PYds/G'].std()
var_value = broncos_data['Off PYds/G'].var()
min_value = broncos_data['Off PYds/G'].min()
max_value = broncos_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = broncos_data['Off PYds/G'].sum()
print("Denver Broncos Offense Passing Yards/Game Mean:", mean_value)
print("Denver Broncos Offense Passing Yards/Game Median:", median_value)
print("Denver Broncos Offense Passing Yards/Game Standard Deviation:", std_value)
print("Denver Broncos Offense Passing Yards/Game Variance:", var_value)
print("Denver Broncos Offense Passing Yards/Game Minimum:", min_value)
print("Denver Broncos Offense Passing Yards/Game Maximum:", max_value)
print("Denver Broncos Offense Passing Yards/Game Range:", data_range)
print("Denver Broncos Total Passing Yards/Game 2012-2022:", total_points)

### Detroit Lions

team_name11 = 'Detroit Lions'
lions_data = nflPass[nflPass['Team'] == team_name11]
mean_value = lions_data['Off PYds/G'].mean()
median_value = lions_data['Off PYds/G'].median()
std_value = lions_data['Off PYds/G'].std()
var_value = lions_data['Off PYds/G'].var()
min_value = lions_data['Off PYds/G'].min()
max_value = lions_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = lions_data['Off PYds/G'].sum()
print("Detroit Lions Offense Passing Yards/Game Mean:", mean_value)
print("Detroit Lions Offense Passing Yards/Games Median:", median_value)
print("Detroit Lions Offense Passing Yards/Game Standard Deviation:", std_value)
print("Detroit Lions Offense Passing Yards/Game Variance:", var_value)
print("Detroit Lions Offense Passing Yards/Game Minimum:", min_value)
print("Detroit Lions Offense Passing Yards/Game Maximum:", max_value)
print("Detroit Lions Offense Passing Yards/Game Range:", data_range)
print("Detroit Lions Total Passing Yards/Game 2012-2022:", total_points)

### Green Bay Packers

team_name12 = 'Green Bay Packers'
packers_data = nflPass[nflPass['Team'] == team_name12]
mean_value = packers_data['Off PYds/G'].mean()
median_value = packers_data['Off PYds/G'].median()
std_value = packers_data['Off PYds/G'].std()
var_value = packers_data['Off PYds/G'].var()
min_value = packers_data['Off PYds/G'].min()
max_value = packers_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = packers_data['Off PYds/G'].sum()
print("Green Bay Packers Offense Passing Yards/Game Mean:", mean_value)
print("Green Bay Packers Offense Passing Yards/Game Median:", median_value)
print("Green Bay Packers Offense Passing Yards/Game Standard Deviation:", std_value)
print("Green Bay Packers Offense Passing Yards/Game Variance:", var_value)
print("Green Bay Packers Offense Passing Yards/Game Minimum:", min_value)
print("Green Bay Packers Offense Passing Yards/Game Maximum:", max_value)
print("Green Bay Packers Offense Passing Yards/Game Range:", data_range)
print("Green Bay Packers Total Passing Yards/Game 2012-2022:", total_points)

### Houston Texans

team_name13 = 'Houston Texans'
texans_data = nflPass[nflPass['Team'] == team_name13]
mean_value = texans_data['Off PYds/G'].mean()
median_value = texans_data['Off PYds/G'].median()
std_value = texans_data['Off PYds/G'].std()
var_value = texans_data['Off PYds/G'].var()
min_value = texans_data['Off PYds/G'].min()
max_value = texans_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = texans_data['Off PYds/G'].sum()
print("Houston Texans Offense Passing Yards/Game Mean:", mean_value)
print("Houston Texans Offense Passing Yards/Game Median:", median_value)
print("Houston Texans Offense Passing Yards/Game Standard Deviation:", std_value)
print("Houston Texans Offense Passing Yards/Game Variance:", var_value)
print("Houston Texans Offense Passing Yards/Game Minimum:", min_value)
print("Houston Texans Offense Passing Yards/Game Maximum:", max_value)
print("Houston Texans Offense Passing Yards/Game Range:", data_range)
print("Houston Texans Total Passing Yards/Game 2012-2022:", total_points)

### Indianapolis Colts

team_name14 = 'Indianapolis Colts'
colts_data = nflPass[nflPass['Team'] == team_name14]
mean_value = colts_data['Off PYds/G'].mean()
median_value = colts_data['Off PYds/G'].median()
std_value = colts_data['Off PYds/G'].std()
var_value = colts_data['Off PYds/G'].var()
min_value = colts_data['Off PYds/G'].min()
max_value = colts_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = colts_data['Off PYds/G'].sum()
print("Indianapolis Colts Offense Passing Yards/Game Mean:", mean_value)
print("Indianapolis Colts Offense Passing Yards/Game Median:", median_value)
print("Indianapolis Colts Offense Passing Yards/Game Standard Deviation:", std_value)
print("Indianapolis Colts Offense Passing Yards/Game Variance:", var_value)
print("Indianapolis Colts Offense Passing Yards/Game Minimum:", min_value)
print("Indianapolis Colts Offense Passing Yards/Game Maximum:", max_value)
print("Indianapolis Colts Offense Passing Yards/Game Range:", data_range)
print("Indianapolis Colts Total Passing Yards/Game 2012-2022:", total_points)

### Jacksonville Jaguars

team_name15 = 'Jacksonville Jaguars'
jaguars_data = nflPass[nflPass['Team'] == team_name15]
mean_value = jaguars_data['Off PYds/G'].mean()
median_value = jaguars_data['Off PYds/G'].median()
std_value = jaguars_data['Off PYds/G'].std()
var_value = jaguars_data['Off PYds/G'].var()
min_value = jaguars_data['Off PYds/G'].min()
max_value = jaguars_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = jaguars_data['Off PYds/G'].sum()
print("Jacksonville Jaguars Offense Passing Yards/Game Mean:", mean_value)
print("Jacksonville Jaguars Offense Passing Yards/Game Median:", median_value)
print("Jacksonville Jaguars Offense Passing Yards/Game Standard Deviation:", std_value)
print("Jacksonville Jaguars Offense Passing Yards/Game Variance:", var_value)
print("Jacksonville Jaguars Offense Passing Yards/Game Minimum:", min_value)
print("Jacksonville Jaguars Offense Passing Yards/Game Maximum:", max_value)
print("Jacksonville Jaguars Offense Passing Yards/Game Range:", data_range)
print("Jacksonville Jaguars Total Passing Yards/Game 2012-2022:", total_points)

### Kansas City Chiefs

team_name16 = 'Kansas City Chiefs'
chiefs_data = nflPass[nflPass['Team'] == team_name16]
mean_value = chiefs_data['Off PYds/G'].mean()
median_value = chiefs_data['Off PYds/G'].median()
std_value = chiefs_data['Off PYds/G'].std()
var_value = chiefs_data['Off PYds/G'].var()
min_value = chiefs_data['Off PYds/G'].min()
max_value = chiefs_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = chiefs_data['Off PYds/G'].sum()
print("Kansas City Chiefs Offense Passing Yards/Game Mean:", mean_value)
print("Kansas City Chiefs Offense Passing Yards/Game Median:", median_value)
print("Kansas City Chiefs Offense Passing Yards/Game Standard Deviation:", std_value)
print("Kansas City Chiefs Offense Passing Yards/Game Variance:", var_value)
print("Kansas City Chiefs Offense Passing Yards/Game Minimum:", min_value)
print("Kansas City Chiefs Offense Passing Yards/Game Maximum:", max_value)
print("Kansas City Chiefs Offense Passing Yards/Game Range:", data_range)
print("Kansas City Chiefs Total Passing Yards/Game 2012-2022:", total_points)

### Las Vegas Raiders

team_name17 = 'Las Vegas Raiders'
raiders_data = nflPass[nflPass['Team'] == team_name17]
mean_value = raiders_data['Off PYds/G'].mean()
median_value = raiders_data['Off PYds/G'].median()
std_value = raiders_data['Off PYds/G'].std()
var_value = raiders_data['Off PYds/G'].var()
min_value = raiders_data['Off PYds/G'].min()
max_value = raiders_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = raiders_data['Off PYds/G'].sum()
print("Las Vegas Raiders Offense Passing Yards/Game Mean:", mean_value)
print("Las Vegas Raiders Offense Passing Yards/Game Median:", median_value)
print("Las Vegas Raiders Offense Passing Yards/Game Standard Deviation:", std_value)
print("Las Vegas Raiders Offense Passing Yards/Game Variance:", var_value)
print("Las Vegas Raiders Offense Passing Yards/Game Minimum:", min_value)
print("Las Vegas Raiders Offense Passing Yards/Game Maximum:", max_value)
print("Las Vegas Raiders Offense Passing Yards/Game Range:", data_range)
print("Las Vegas Raiders Total Passing Yards/Game 2012-2022:", total_points)

### Los Angeles Chargers

team_name18 = 'Los Angeles Chargers'
chargers_data = nflPass[nflPass['Team'] == team_name18]
mean_value = chargers_data['Off PYds/G'].mean()
median_value = chargers_data['Off PYds/G'].median()
std_value = chargers_data['Off PYds/G'].std()
var_value = chargers_data['Off PYds/G'].var()
min_value = chargers_data['Off PYds/G'].min()
max_value = chargers_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = chargers_data['Off PYds/G'].sum()
print("Los Angeles Chargers Offense Passing Yards/Game Mean:", mean_value)
print("Los Angeles Chargers Offense Passing Yards/Game Median:", median_value)
print("Los Angeles Chargers Offense Passing Yards/Game Standard Deviation:", std_value)
print("Los Angeles Chargers Offense Passing Yards/Game Variance:", var_value)
print("Los Angeles Chargers Offense Passing Yards/Game Minimum:", min_value)
print("Los Angeles Chargers Offense Passing Yards/Game Maximum:", max_value)
print("Los Angeles Chargers Offense Passing Yards/Game Range:", data_range)
print("Los Angeles Chargers Total Passing Yards/Game 2012-2022:", total_points)


### Los Angeles Rams

team_name19 = 'Los Angeles Rams'
Rams_data = nflPass[nflPass['Team'] == team_name19]
mean_value = Rams_data['Off PYds/G'].mean()
median_value = Rams_data['Off PYds/G'].median()
std_value = Rams_data['Off PYds/G'].std()
var_value = Rams_data['Off PYds/G'].var()
min_value = Rams_data['Off PYds/G'].min()
max_value = Rams_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = Rams_data['Off PYds/G'].sum()
print("Los Angeles Rams Offense Passing Yards/Game Mean:", mean_value)
print("Los Angeles Rams Offense Passing Yards/Game Median:", median_value)
print("Los Angeles Rams Offense Passing Yards/Game Standard Deviation:", std_value)
print("Los Angeles Rams Offense Passing Yards/Game Variance:", var_value)
print("Los Angeles Rams Offense Passing Yards/Game Minimum:", min_value)
print("Los Angeles Rams Offense Passing Yards/Game Maximum:", max_value)
print("Los Angeles Rams Offense Passing Yards/Game Range:", data_range)
print("Los Angeles Rams Total Passing Yards/Game 2012-2022:", total_points)

### Miami Dolphins

team_name20 = 'Miami Dolphins'
dolphins_data = nflPass[nflPass['Team'] == team_name20]
mean_value = dolphins_data['Off PYds/G'].mean()
median_value = dolphins_data['Off PYds/G'].median()
std_value = dolphins_data['Off PYds/G'].std()
var_value = dolphins_data['Off PYds/G'].var()
min_value = dolphins_data['Off PYds/G'].min()
max_value = dolphins_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = dolphins_data['Off PYds/G'].sum()
print("Miami Dolphins Offense Passing Yards/Game Mean:", mean_value)
print("Miami Dolphins Offense Passing Yards/Game Median:", median_value)
print("Miami Dolphins Offense Passing Yards/Game Standard Deviation:", std_value)
print("Miami Dolphins Offense Passing Yards/Game Variance:", var_value)
print("Miami Dolphins Offense Passing Yards/Game Minimum:", min_value)
print("Miami Dolphins Offense Passing Yards/Game Maximum:", max_value)
print("Miami Dolphins Offense Passing Yards/Game Range:", data_range)
print("Miami Dolphins Total Passing Yards/Game 2012-2022:", total_points)

### Minnesota Vikings

team_name21 = 'Minnesota Vikings'
vikings_data = nflPass[nflPass['Team'] == team_name21]
mean_value = vikings_data['Off PYds/G'].mean()
median_value = vikings_data['Off PYds/G'].median()
std_value = vikings_data['Off PYds/G'].std()
var_value = vikings_data['Off PYds/G'].var()
min_value = vikings_data['Off PYds/G'].min()
max_value = vikings_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = vikings_data['Off PYds/G'].sum()
print("Minnesota Vikings Offense Passing Yards/Game Mean:", mean_value)
print("Minnesota Vikings Offense Passing Yards/Game Median:", median_value)
print("Minnesota Vikings Offense Passing Yards/Game Standard Deviation:", std_value)
print("Minnesota Vikings Offense Passing Yards/Game Variance:", var_value)
print("Minnesota Vikings Offense Passing Yards/Game Minimum:", min_value)
print("Minnesota Vikings Offense Passing Yards/Game Maximum:", max_value)
print("Minnesota Vikings Offense Passing Yards/Game Range:", data_range)
print("Minnesota Vikings Total Passing Yards/Game 2012-2022:", total_points)

### New England Patriots

team_name22 = 'New England Patriots'
patriots_data = nflPass[nflPass['Team'] == team_name22]
mean_value = patriots_data['Off PYds/G'].mean()
median_value = patriots_data['Off PYds/G'].median()
std_value = patriots_data['Off PYds/G'].std()
var_value = patriots_data['Off PYds/G'].var()
min_value = patriots_data['Off PYds/G'].min()
max_value = patriots_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = patriots_data['Off PYds/G'].sum()
print("New England Patriots Offense Passing Yards/Game Mean:", mean_value)
print("New England Patriots Offense Passing Yards/Game Median:", median_value)
print("New England Patriots Offense Passing Yards/Game Standard Deviation:", std_value)
print("New England Patriots Offense Passing Yards/Game Variance:", var_value)
print("New England Patriots Offense Passing Yards/Game Minimum:", min_value)
print("New England Patriots Offense Passing Yards/Game Maximum:", max_value)
print("New England Patriots Offense Passing Yards/Game Range:", data_range)
print("New England Patriots Total Passing Yards/Game 2012-2022:", total_points)

### New Orleans Saints

team_name23 = 'New Orleans Saints'
saints_data = nflPass[nflPass['Team'] == team_name23]
mean_value = saints_data['Off PYds/G'].mean()
median_value = saints_data['Off PYds/G'].median()
std_value = saints_data['Off PYds/G'].std()
var_value = saints_data['Off PYds/G'].var()
min_value = saints_data['Off PYds/G'].min()
max_value = saints_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = saints_data['Off PYds/G'].sum()
print("New Orleans Saints Offense Passing Yards/Game Mean:", mean_value)
print("New Orleans Saints Offense Passing Yards/Game Median:", median_value)
print("New Orleans Saints Offense Passing Yards/Game Standard Deviation:", std_value)
print("New Orleans Saints Offense Passing Yards/Game Variance:", var_value)
print("New Orleans Saints Offense Passing Yards/Game Minimum:", min_value)
print("New Orleans Saints Offense Passing Yards/Game Maximum:", max_value)
print("New Orleans Saints Offense Passing Yards/Game Range:", data_range)
print("New Orleans Saints Total Passing Yards/Game 2012-2022:", total_points)

### New York Giants

team_name24 = 'New York Giants'
giants_data = nflPass[nflPass['Team'] == team_name24]
mean_value = giants_data['Off PYds/G'].mean()
median_value = giants_data['Off PYds/G'].median()
std_value = giants_data['Off PYds/G'].std()
var_value = giants_data['Off PYds/G'].var()
min_value = giants_data['Off PYds/G'].min()
max_value = giants_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = giants_data['Off PYds/G'].sum()
print("New York Giants Offense Passing Yards/Game Mean:", mean_value)
print("New York Giants Offense Passing Yards/Game Median:", median_value)
print("New York Giants Offense Passing Yards/Game Standard Deviation:", std_value)
print("New York Giants Offense Passing Yards/Game Variance:", var_value)
print("New York Giants Offense Passing Yards/Game Minimum:", min_value)
print("New York Giants Offense Passing Yards/Game Maximum:", max_value)
print("New York Giants Offense Passing Yards/Game Range:", data_range)
print("New York Giants Total Passing Yards/Game 2012-2022:", total_points)

### New York Jets

team_name25 = 'New York Jets'
Jets_data = nflPass[nflPass['Team'] == team_name25]
mean_value = Jets_data['Off PYds/G'].mean()
median_value = Jets_data['Off PYds/G'].median()
std_value = Jets_data['Off PYds/G'].std()
var_value = Jets_data['Off PYds/G'].var()
min_value = Jets_data['Off PYds/G'].min()
max_value = Jets_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = Jets_data['Off PYds/G'].sum()
print("New York Jets Offense Passing Yards/Game Mean:", mean_value)
print("New York Jets Offense Passing Yards/Game Median:", median_value)
print("New York Jets Offense Passing Yards/Game Standard Deviation:", std_value)
print("New York Jets Offense Passing Yards/Game Variance:", var_value)
print("New York Jets Offense Passing Yards/Game Minimum:", min_value)
print("New York Jets Offense Passing Yards/Game Maximum:", max_value)
print("New York Jets Offense Passing Yards/Game Range:", data_range)
print("New York Jets Total Passing Yards/Game 2012-2022:", total_points)

### Philadelphia Eagles

team_name26 = 'Philadelphia Eagles'
eagles_data = nflPass[nflPass['Team'] == team_name26]
mean_value = eagles_data['Off PYds/G'].mean()
median_value = eagles_data['Off PYds/G'].median()
std_value = eagles_data['Off PYds/G'].std()
var_value = eagles_data['Off PYds/G'].var()
min_value = eagles_data['Off PYds/G'].min()
max_value = eagles_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = eagles_data['Off PYds/G'].sum()
print("Philadelphia Eagles Offense Passing Yards/Game Mean:", mean_value)
print("Philadelphia Eagles Offense Passing Yards/Game Median:", median_value)
print("Philadelphia Eagles Offense Passing Yards/Game Standard Deviation:", std_value)
print("Philadelphia Eagles Offense Passing Yards/Game Variance:", var_value)
print("Philadelphia Eagles Offense Passing Yards/Game Minimum:", min_value)
print("Philadelphia Eagles Offense Passing Yards/Game Maximum:", max_value)
print("Philadelphia Eagles Offense Passing Yards/Game Range:", data_range)
print("Philadelphia Eagles Total Passing Yards/Game 2012-2022:", total_points)

### Pittsburgh Steelers

team_name27 = 'Pittsburgh Steelers'
steelers_data = nflPass[nflPass['Team'] == team_name27]
mean_value = steelers_data['Off PYds/G'].mean()
median_value = steelers_data['Off PYds/G'].median()
std_value = steelers_data['Off PYds/G'].std()
var_value = steelers_data['Off PYds/G'].var()
min_value = steelers_data['Off PYds/G'].min()
max_value = steelers_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = steelers_data['Off PYds/G'].sum()
print("Pittsburgh Steelers Offense Passing Yards/Game Mean:", mean_value)
print("Pittsburgh Steelers Offense Passing Yards/Game Median:", median_value)
print("Pittsburgh Steelers Offense Passing Yards/Game Standard Deviation:", std_value)
print("Pittsburgh Steelers Offense Passing Yards/Game Variance:", var_value)
print("Pittsburgh Steelers Offense Passing Yards/Game Minimum:", min_value)
print("Pittsburgh Steelers Offense Passing Yards/Game Maximum:", max_value)
print("Pittsburgh Steelers Offense Passing Yards/Game Range:", data_range)
print("Pittsburgh Steelers Total Passing Yards/Game 2012-2022:", total_points)

### San Francisco 49ers

team_name28 = 'San Francisco 49ers'
niners_data = nflPass[nflPass['Team'] == team_name28]
mean_value = niners_data['Off PYds/G'].mean()
median_value = niners_data['Off PYds/G'].median()
std_value = niners_data['Off PYds/G'].std()
var_value = niners_data['Off PYds/G'].var()
min_value = niners_data['Off PYds/G'].min()
max_value = niners_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = niners_data['Off PYds/G'].sum()
print("San Francisco 49ers Offense Passing Yards/Game Mean:", mean_value)
print("San Francisco 49ers Offense Passing Yards/Game Median:", median_value)
print("San Francisco 49ers Offense Passing Yards/Game Standard Deviation:", std_value)
print("San Francisco 49ers Offense Passing Yards/Game Variance:", var_value)
print("San Francisco 49ers Offense Passing Yards/Game Minimum:", min_value)
print("San Francisco 49ers Offense Passing Yards/Game Maximum:", max_value)
print("San Francisco 49ers Offense Passing Yards/Game Rushing YardsRange:", data_range)
print("San Francisco 49ers Total Passing Yards/Game 2012-2022:", total_points)

### Tampa Bay Buccaneers

team_name29 = 'Tampa Bay Buccaneers'
buccaneers_data = nflPass[nflPass['Team'] == team_name29]
mean_value = buccaneers_data['Off PYds/G'].mean()
median_value = buccaneers_data['Off PYds/G'].median()
std_value = buccaneers_data['Off PYds/G'].std()
var_value = buccaneers_data['Off PYds/G'].var()
min_value = buccaneers_data['Off PYds/G'].min()
max_value = buccaneers_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = buccaneers_data['Off PYds/G'].sum()
print("Tampa Bay Buccaneers Offense Passing Yards/Game Mean:", mean_value)
print("Tampa Bay Buccaneers Offense Passing Yards/Game Median:", median_value)
print("Tampa Bay Buccaneers Offense Passing Yards/Game Standard Deviation:", std_value)
print("Tampa Bay Buccaneers Offense Passing Yards/Game Variance:", var_value)
print("Tampa Bay Buccaneers Offense Passing Yards/Game Minimum:", min_value)
print("Tampa Bay Buccaneers Offense Passing Yards/Game Maximum:", max_value)
print("Tampa Bay Buccaneers Offense Passing Yards/Game Range:", data_range)
print("Tampa Bay Buccaneers Total Passing Yards/Game 2012-2022:", total_points)

### Tennessee Titans

team_name30 = 'Tennessee Titans'
titans_data = nflPass[nflPass['Team'] == team_name30]
mean_value = titans_data['Off PYds/G'].mean()
median_value = titans_data['Off PYds/G'].median()
std_value = titans_data['Off PYds/G'].std()
var_value = titans_data['Off RYds/G'].var()
min_value = titans_data['Off PYds/G'].min()
max_value = titans_data['Off PYds/G'].max()
data_range = max_value - min_value
total_points = titans_data['Off PYds/G'].sum()
print("Tennessee Titans Offense Passing Yards/Game Mean:", mean_value)
print("Tennessee Titans Offense Passing Yards/Game Median:", median_value)
print("Tennessee Titans Offense Passing Yards/Game Standard Deviation:", std_value)
print("Tennessee Titans Offense Passing Yards/Game Variance:", var_value)
print("Tennessee Titans Offense Passing Yards/Game Minimum:", min_value)
print("Tennessee Titans Offense Passing Yards/Game Maximum:", max_value)
print("Tennessee Titans Offense Passing Yards/Game Range:", data_range)
print("Tennessee Titans Total Passing Yards/Game 2012-2022:", total_points)

### Washington Commanders

team_name31 = 'Washington Commanders'
commanders_data = nflPass[nflPass['Team'] == team_name31]
mean_value = commanders_data['Off PYds/G'].mean()
median_value = commanders_data['Off PYds/G'].median()
std_value = commanders_data['Off PYds/G'].std()
var_value = commanders_data['Off PYds/G'].var()
min_value = commanders_data['Off PYds/G'].min()
max_value = commanders_data['Off PYds/G'].max()
total_points = commanders_data['Off PYds/G'].sum()
data_range = max_value - min_value
print("Washington Commanders Offense Passing Yards/Game Mean:", mean_value)
print("Washington Commanders Offense Passing Yards/Game Median:", median_value)
print("Washington Commanders Offense Passing Yards/Game Standard Deviation:", std_value)
print("Washington Commanders Offense Passing Yards/Game Variance:", var_value)
print("Washington Commanders Offense Passing Yards/Game Minimum:", min_value)
print("Washington Commanders Offense Passing Yards/Game Points Maximum:", max_value)
print("Washington Commanders Offense Passing Yards/Game Range:", data_range)
print("Washington Commanders Total Passing Yards/Game 2012-2022:", total_points)
# Out:
# Arizona Cardinals Offense Passing Yards/Game Mean: 236.8
# Arizona Cardinals Offense Passing Yards/Game Median: 238.0
# Arizona Cardinals Offense Passing Yards/Game Standard Deviation: 26.662107943671664
# Arizona Cardinals Offense Passing Yards/Game Variance: 710.8679999999997
# Arizona Cardinals Offense Passing Yards/Game Minimum: 187.8
# Arizona Cardinals Offense Passing Yards/Game Maximum: 288.5
# Arizona Cardinals Offense Passing Yards/Game Range: 100.69999999999999
# Arizona Cardinals Total Passing Yards/Game 2012-2022: 2604.8
# Atlanta Falcons Offense Passing Yards/Game Mean: 258.53636363636366
# Atlanta Falcons Offense Passing Yards/Game Median: 272.7
# Atlanta Falcons Offense Passing Yards/Game Standard Deviation: 40.09092846835236
# Atlanta Falcons Offense Passing Yards/Game Variance: 1607.2825454545455
# Atlanta Falcons Offense Passing Yards/Game Minimum: 158.8
# Atlanta Falcons Offense Passing Yards/Game Maximum: 295.3
# Atlanta Falcons Offense Passing Yards/Game Range: 136.5
# Atlanta Falcons Total Passing Yards/Game 2012-2022: 2843.9
# Baltimore Ravens Offense Passing Yards/Game Mean: 216.66363636363639
# Baltimore Ravens Offense Passing Yards/Game Median: 224.4
# Baltimore Ravens Offense Passing Yards/Game Standard Deviation: 32.25446551184107
# Baltimore Ravens Offense Passing Yards/Game Variance: 1040.350545454545
# Baltimore Ravens Offense Passing Yards/Game Minimum: 171.2
# Baltimore Ravens Offense Passing Yards/Game Maximum: 266.9
# Baltimore Ravens Offense Passing Yards/Game  Range: 95.69999999999999
# Baltimore Ravens Total Passing Yards/Game 2012-2022: 2383.3
# Buffalo Bills Offense Passing Yards/Game Mean: 216.0636363636363
# Buffalo Bills Offense Passing Yards/Game Median: 204.3
# Buffalo Bills Offense Passing Yards/Game Standard Deviation: 36.24186178239945
# Buffalo Bills Offense Passing Yards/Game Variance: 1313.4725454545455
# Buffalo Bills Offense Passing Yards/Game Minimum: 176.6
# Buffalo Bills Offense Passing Yards/Game Maximum: 288.8
# Buffalo Bills Offense Passing Yards/Game Range: 112.20000000000002
# Buffalo Bills Total Passing Yards/Game 2012-2022: 2376.7
# Carolina Panthers Offense Passing Yards/Game Mean: 210.61818181818174
# Carolina Panthers Offense Passing Yards/Game Median: 219.4
# Carolina Panthers Offense Passing Yards/Game Standard Deviation: 22.50932332087387
# Carolina Panthers Offense Passing Yards/Game Variance: 506.6696363636364
# Carolina Panthers Offense Passing Yards/Game Minimum: 176.2
# Carolina Panthers Offense Passing Yards/Game Maximum: 243.0
# Carolina Panthers Offense Passing Yards/Game Range: 66.80000000000001
# Carolina Panthers Total Passing Yards/Game 2012-2022: 2316.7999999999997
# Chicago Bears Offense Passing Yards/Game Mean: 206.6818181818182
# Chicago Bears Offense Passing Yards/Game Median: 205.7
# Chicago Bears Offense Passing Yards/Game Standard Deviation: 39.66068123927824
# Chicago Bears Offense Passing Yards/Game Variance: 1572.9696363636367
# Chicago Bears Offense Passing Yards/Game Minimum: 130.5
# Chicago Bears Offense Passing Yards/Game Maximum: 267.6
# Chicago Bears Offense Passing Yards/Game Range: 137.10000000000002
# Chicago Bears Total Passing Yards/Game 2012-2022: 2273.5
# Cincinnati Bengals Offense Passing Yards/Game Mean: 231.4
# Cincinnati Bengals Offense Passing Yards/Game Median: 228.2
# Cincinnati Bengals Offense Passing Yards/Game Standard Deviation: 25.118917174114017
# Cincinnati Bengals Offense Passing Yards/Game Variance: 630.96
# Cincinnati Bengals Offense Passing Yards/Game Minimum: 195.1
# Cincinnati Bengals Offense Passing Yards/Game Maximum: 265.0
# Cincinnati Bengals Offense Passing Yards/Game Range: 69.9
# Cincinnati Bengals Total Passing Yards/Game 2012-2022: 2545.4
# Cleveland Browns Offense Passing Yards/Game Mean: 215.39999999999998
# Cleveland Browns Offense Passing Yards/Game Median: 214.7
# Cleveland Browns Offense Passing Yards/Game Standard Deviation: 17.307339483583256
# Cleveland Browns Offense Passing Yards/Game Variance: 299.544
# Cleveland Browns Offense Passing Yards/Game Minimum: 195.3
# Cleveland Browns Offense Passing Yards/Game Maximum: 252.9
# Cleveland Browns Offense Passing Yards/Game Range: 57.599999999999994
# Cleveland Browns Total Passing Yards/Game 2012-2022: 2369.4
# Dallas Cowboys Offense Passing Yards/Game Mean: 243.16363636363639
# Dallas Cowboys Offense Passing Yards/Game Median: 236.5
# Dallas Cowboys Offense Passing Yards/Game Standard Deviation: 36.62778379119524
# Dallas Cowboys Offense Passing Yards/Game Variance: 1341.594545454545
# Dallas Cowboys Offense Passing Yards/Game Minimum: 196.3
# Dallas Cowboys Offense Passing Yards/Game Maximum: 296.9
# Dallas Cowboys Offense Passing Yards/Game Range: 100.59999999999997
# Dallas Cowboys Total Passing Yards/Game 2012-2022: 2674.8
# Denver Broncos Offense Passing Yards/Game Mean: 240.27272727272728
# Denver Broncos Offense Passing Yards/Game Median: 215.7
# Denver Broncos Offense Passing Yards/Game Standard Deviation: 45.83468317571511
# Denver Broncos Offense Passing Yards/Game Variance: 2100.8181818181815
# Denver Broncos Offense Passing Yards/Game Minimum: 194.7
# Denver Broncos Offense Passing Yards/Game Maximum: 340.2
# Denver Broncos Offense Passing Yards/Game Range: 145.5
# Denver Broncos Total Passing Yards/Game 2012-2022: 2643.0
# Detroit Lions Offense Passing Yards/Game Mean: 258.7727272727273
# Detroit Lions Offense Passing Yards/Games Median: 256.9
# Detroit Lions Offense Passing Yards/Game Standard Deviation: 23.357486633158576
# Detroit Lions Offense Passing Yards/Game Variance: 545.5721818181815
# Detroit Lions Offense Passing Yards/Game Minimum: 211.6
# Detroit Lions Offense Passing Yards/Game Maximum: 307.9
# Detroit Lions Offense Passing Yards/Game Range: 96.29999999999998
# Detroit Lions Total Passing Yards/Game 2012-2022: 2846.5
# Green Bay Packers Offense Passing Yards/Game Mean: 238.23636363636368
# Green Bay Packers Offense Passing Yards/Game Median: 253.1
# Green Bay Packers Offense Passing Yards/Game Standard Deviation: 26.92018843646057
# Green Bay Packers Offense Passing Yards/Game Variance: 724.6965454545455
# Green Bay Packers Offense Passing Yards/Game Minimum: 197.9
# Green Bay Packers Offense Passing Yards/Game Maximum: 266.8
# Green Bay Packers Offense Passing Yards/Game Range: 68.9
# Green Bay Packers Total Passing Yards/Game 2012-2022: 2620.6
# Houston Texans Offense Passing Yards/Game Mean: 222.3818181818182
# Houston Texans Offense Passing Yards/Game Median: 209.5
# Houston Texans Offense Passing Yards/Game Standard Deviation: 27.520349495666597
# Houston Texans Offense Passing Yards/Game Variance: 757.3696363636367
# Houston Texans Offense Passing Yards/Game Minimum: 194.4
# Houston Texans Offense Passing Yards/Game Maximum: 283.6
# Houston Texans Offense Passing Yards/Game Range: 89.20000000000002
# Houston Texans Total Passing Yards/Game 2012-2022: 2446.2
# Indianapolis Colts Offense Passing Yards/Game Mean: 227.22727272727272
# Indianapolis Colts Offense Passing Yards/Game Median: 231.5
# Indianapolis Colts Offense Passing Yards/Game Standard Deviation: 40.03973253929379
# Indianapolis Colts Offense Passing Yards/Game Variance: 1603.1801818181816
# Indianapolis Colts Offense Passing Yards/Game Minimum: 180.8
# Indianapolis Colts Offense Passing Yards/Game Maximum: 305.9
# Indianapolis Colts Offense Passing Yards/Game Range: 125.09999999999997
# Indianapolis Colts Total Passing Yards/Game 2012-2022: 2499.5
# Jacksonville Jaguars Offense Passing Yards/Game Mean: 223.3272727272727
# Jacksonville Jaguars Offense Passing Yards/Game Median: 224.6
# Jacksonville Jaguars Offense Passing Yards/Game Standard Deviation: 18.42417384357252
# Jacksonville Jaguars Offense Passing Yards/Game Variance: 339.45018181818193
# Jacksonville Jaguars Offense Passing Yards/Game Minimum: 187.6
# Jacksonville Jaguars Offense Passing Yards/Game Maximum: 256.8
# Jacksonville Jaguars Offense Passing Yards/Game Range: 69.20000000000002
# Jacksonville Jaguars Total Passing Yards/Game 2012-2022: 2456.6000000000004
# Kansas City Chiefs Offense Passing Yards/Game Mean: 244.69090909090912
# Kansas City Chiefs Offense Passing Yards/Game Median: 256.5
# Kansas City Chiefs Offense Passing Yards/Game Standard Deviation: 44.82868399909715
# Kansas City Chiefs Offense Passing Yards/Game Variance: 2009.6109090909092
# Kansas City Chiefs Offense Passing Yards/Game Minimum: 169.6
# Kansas City Chiefs Offense Passing Yards/Game Maximum: 303.4
# Kansas City Chiefs Offense Passing Yards/Game Range: 133.79999999999998
# Kansas City Chiefs Total Passing Yards/Game 2012-2022: 2691.6000000000004
# Las Vegas Raiders Offense Passing Yards/Game Mean: 238.82727272727277
# Las Vegas Raiders Offense Passing Yards/Game Median: 242.4
# Las Vegas Raiders Offense Passing Yards/Game Standard Deviation: 21.063479812656357
# Las Vegas Raiders Offense Passing Yards/Game Variance: 443.67018181818196
# Las Vegas Raiders Offense Passing Yards/Game Minimum: 204.7
# Las Vegas Raiders Offense Passing Yards/Game Maximum: 268.6
# Las Vegas Raiders Offense Passing Yards/Game Range: 63.900000000000034
# Las Vegas Raiders Total Passing Yards/Game 2012-2022: 2627.1
# Los Angeles Chargers Offense Passing Yards/Game Mean: 266.79999999999995
# Los Angeles Chargers Offense Passing Yards/Game Median: 270.6
# Los Angeles Chargers Offense Passing Yards/Game Standard Deviation: 21.96829533668918
# Los Angeles Chargers Offense Passing Yards/Game Variance: 482.60599999999965
# Los Angeles Chargers Offense Passing Yards/Game Minimum: 205.9
# Los Angeles Chargers Offense Passing Yards/Game Maximum: 286.9
# Los Angeles Chargers Offense Passing Yards/Game Range: 80.99999999999997
# Los Angeles Chargers Total Passing Yards/Game 2012-2022: 2934.7999999999997
# Los Angeles Rams Offense Passing Yards/Game Mean: 223.2909090909091
# Los Angeles Rams Offense Passing Yards/Game Median: 221.9
# Los Angeles Rams Offense Passing Yards/Game Standard Deviation: 36.705161886183106
# Los Angeles Rams Offense Passing Yards/Game Variance: 1347.2689090909091
# Los Angeles Rams Offense Passing Yards/Game Minimum: 175.3
# Los Angeles Rams Offense Passing Yards/Game Maximum: 281.2
# Los Angeles Rams Offense Passing Yards/Game Range: 105.89999999999998
# Los Angeles Rams Total Passing Yards/Game 2012-2022: 2456.2000000000003
# Miami Dolphins Offense Passing Yards/Game Mean: 227.74545454545458
# Miami Dolphins Offense Passing Yards/Game Median: 222.9
# Miami Dolphins Offense Passing Yards/Game Standard Deviation: 16.99090130842761
# Miami Dolphins Offense Passing Yards/Game Variance: 288.69072727272703
# Miami Dolphins Offense Passing Yards/Game Minimum: 198.9
# Miami Dolphins Offense Passing Yards/Game Maximum: 265.4
# Miami Dolphins Offense Passing Yards/Game Range: 66.49999999999997
# Miami Dolphins Total Passing Yards/Game 2012-2022: 2505.2000000000003
# Minnesota Vikings Offense Passing Yards/Game Mean: 224.0727272727273
# Minnesota Vikings Offense Passing Yards/Game Median: 234.6
# Minnesota Vikings Offense Passing Yards/Game Standard Deviation: 28.915950301143173
# Minnesota Vikings Offense Passing Yards/Game Variance: 836.132181818182
# Minnesota Vikings Offense Passing Yards/Game Minimum: 171.9
# Minnesota Vikings Offense Passing Yards/Game Maximum: 263.8
# Minnesota Vikings Offense Passing Yards/Game Range: 91.9
# Minnesota Vikings Total Passing Yards/Game 2012-2022: 2464.8
# New England Patriots Offense Passing Yards/Game Mean: 252.3272727272727
# New England Patriots Offense Passing Yards/Game Median: 257.6
# New England Patriots Offense Passing Yards/Game Standard Deviation: 34.552831748182115
# New England Patriots Offense Passing Yards/Game Variance: 1193.898181818182
# New England Patriots Offense Passing Yards/Game Minimum: 180.6
# New England Patriots Offense Passing Yards/Game Maximum: 291.4
# New England Patriots Offense Passing Yards/Game Range: 110.79999999999998
# New England Patriots Total Passing Yards/Game 2012-2022: 2775.6
# New Orleans Saints Offense Passing Yards/Game Mean: 271.16999999999996
# New Orleans Saints Offense Passing Yards/Game Median: 281.5
# New Orleans Saints Offense Passing Yards/Game Standard Deviation: 45.639725629713816
# New Orleans Saints Offense Passing Yards/Game Variance: 2082.984555555556
# New Orleans Saints Offense Passing Yards/Game Minimum: 187.4
# New Orleans Saints Offense Passing Yards/Game Maximum: 317.1
# New Orleans Saints Offense Passing Yards/Game Range: 129.70000000000002
# New Orleans Saints Total Passing Yards/Game 2012-2022: 2711.7000000000003
# New York Giants Offense Passing Yards/Game Mean: 224.9909090909091
# New York Giants Offense Passing Yards/Game Median: 224.2
# New York Giants Offense Passing Yards/Game Standard Deviation: 29.671921223454827
# New York Giants Offense Passing Yards/Game Variance: 880.422909090909
# New York Giants Offense Passing Yards/Game Minimum: 185.7
# New York Giants Offense Passing Yards/Game Maximum: 271.4
# New York Giants Offense Passing Yards/Game Range: 85.69999999999999
# New York Giants Total Passing Yards/Game 2012-2022: 2474.8999999999996
# New York Jets Offense Passing Yards/Game Mean: 201.13636363636363
# New York Jets Offense Passing Yards/Game Median: 198.9
# New York Jets Offense Passing Yards/Game Standard Deviation: 22.672815119754
# New York Jets Offense Passing Yards/Game Variance: 514.0565454545455
# New York Jets Offense Passing Yards/Game Minimum: 174.8
# New York Jets Offense Passing Yards/Game Maximum: 253.6
# New York Jets Offense Passing Yards/Game Range: 78.79999999999998
# New York Jets Total Passing Yards/Game 2012-2022: 2212.5
# Philadelphia Eagles Offense Passing Yards/Game Mean: 236.5363636363636
# Philadelphia Eagles Offense Passing Yards/Game Median: 236.9
# Philadelphia Eagles Offense Passing Yards/Game Standard Deviation: 20.949571486179508
# Philadelphia Eagles Offense Passing Yards/Game Variance: 438.88454545454545
# Philadelphia Eagles Offense Passing Yards/Game Minimum: 200.2
# Philadelphia Eagles Offense Passing Yards/Game Maximum: 272.2
# Philadelphia Eagles Offense Passing Yards/Game Range: 72.0
# Philadelphia Eagles Total Passing Yards/Game 2012-2022: 2601.8999999999996
# Pittsburgh Steelers Offense Passing Yards/Game Mean: 249.69090909090903
# Pittsburgh Steelers Offense Passing Yards/Game Median: 251.1
# Pittsburgh Steelers Offense Passing Yards/Game Standard Deviation: 35.80987167096399
# Pittsburgh Steelers Offense Passing Yards/Game Variance: 1282.3469090909095
# Pittsburgh Steelers Offense Passing Yards/Game Minimum: 186.3
# Pittsburgh Steelers Offense Passing Yards/Game Maximum: 301.6
# Pittsburgh Steelers Offense Passing Yards/Game Range: 115.30000000000001
# Pittsburgh Steelers Total Passing Yards/Game 2012-2022: 2746.5999999999995
# San Francisco 49ers Offense Passing Yards/Game Mean: 220.6909090909091
# San Francisco 49ers Offense Passing Yards/Game Median: 226.8
# San Francisco 49ers Offense Passing Yards/Game Standard Deviation: 26.85242836487809
# San Francisco 49ers Offense Passing Yards/Game Variance: 721.0529090909093
# San Francisco 49ers Offense Passing Yards/Game Minimum: 181.9
# San Francisco 49ers Offense Passing Yards/Game Maximum: 252.1
# San Francisco 49ers Offense Passing Yards/Game Rushing YardsRange: 70.19999999999999
# San Francisco 49ers Total Passing Yards/Game 2012-2022: 2427.6000000000004
# Tampa Bay Buccaneers Offense Passing Yards/Game Mean: 257.50000000000006
# Tampa Bay Buccaneers Offense Passing Yards/Game Median: 269.8
# Tampa Bay Buccaneers Offense Passing Yards/Game Standard Deviation: 39.9213977711202
# Tampa Bay Buccaneers Offense Passing Yards/Game Variance: 1593.7180000000008
# Tampa Bay Buccaneers Offense Passing Yards/Game Minimum: 176.2
# Tampa Bay Buccaneers Offense Passing Yards/Game Maximum: 307.6
# Tampa Bay Buccaneers Offense Passing Yards/Game Range: 131.40000000000003
# Tampa Bay Buccaneers Total Passing Yards/Game 2012-2022: 2832.5
# Tennessee Titans Offense Passing Yards/Game Mean: 209.3727272727273
# Tennessee Titans Offense Passing Yards/Game Median: 213.2
# Tennessee Titans Offense Passing Yards/Game Standard Deviation: 16.16274054169595
# Tennessee Titans Offense Passing Yards/Game Variance: 526.2061818181817
# Tennessee Titans Offense Passing Yards/Game Minimum: 171.4
# Tennessee Titans Offense Passing Yards/Game Maximum: 228.3
# Tennessee Titans Offense Passing Yards/Game Range: 56.900000000000006
# Tennessee Titans Total Passing Yards/Game 2012-2022: 2303.1
# Washington Commanders Offense Passing Yards/Game Mean: 229.3
# Washington Commanders Offense Passing Yards/Game Median: 234.4
# Washington Commanders Offense Passing Yards/Game Standard Deviation: 32.54916281565472
# Washington Commanders Offense Passing Yards/Game Variance: 1059.4479999999999
# Washington Commanders Offense Passing Yards/Game Minimum: 175.8
# Washington Commanders Offense Passing Yards/Game Points Maximum: 297.4
# Washington Commanders Offense Passing Yards/Game Range: 121.59999999999997
# Washington Commanders Total Passing Yards/Game 2012-2022: 2522.2999999999997
